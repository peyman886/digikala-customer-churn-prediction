# %% [markdown]
# # 🤖 Churn Prediction - ML Modeling Experiments
#
# **اصل اساسی: برای هر سگمنت یک مدل جداگانه آموزش می‌دهیم**
#
# ## 📋 فهرست آزمایش‌ها:
#
# 1. **Rule-Based Baseline** - مدل ساده بر اساس recency
# 2. **Per-Segment vs Unified** - مقایسه مدل جداگانه vs یکپارچه
# 3. **Model Comparison (Per-Segment)** - برای هر سگمنت: XGBoost vs LightGBM vs RF vs LogReg
# 4. **Segment Configurations** - تست 3, 4, 5, 6 سگمنت (Per-Segment)
# 5. **Auto-Clustering** - کلاسترینگ خودکار (Per-Cluster models)
# 6. **Hyperparameter Tuning** - بهینه‌سازی هایپرپارامترها برای هر سگمنت
# 7. **Threshold Optimization** - بهینه‌سازی threshold برای weighted_recall
# 8. **Feature Importance & SHAP Analysis** - تحلیل feature importance برای هر سگمنت
#
# **متریک اصلی: Weighted Recall**

# %% [markdown]
# ## 0️⃣ Setup

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
from pathlib import Path
from datetime import datetime
from typing import Dict, List, Tuple
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# Our modules
from src.models import (
    get_model, MLModelFactory, RuleBasedBaseline, Segmenter, ModelConfig,
    calculate_class_weight, train_per_segment_models, calculate_weighted_recall,
    print_segment_results, find_optimal_threshold_per_segment
)
from src.evaluation import MetricsCalculator, SegmentWeights, get_optimal_threshold
from src.visualization import (
    plot_confusion_matrix, plot_roc_curves, plot_pr_curves,
    plot_feature_importance, plot_metrics_comparison,
    plot_threshold_analysis, plot_segment_distribution,
    set_plot_style, SEGMENT_COLORS, MODEL_COLORS
)

# SHAP
import shap

# Sklearn
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, classification_report
)

# Settings
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
set_plot_style()

print('✅ All modules loaded!')
# Out:
# ✅ All modules loaded!

# %%
# =============================================================================
# CONFIGURATION
# =============================================================================

DATA_DIR = '../data/processed'
RESULTS_DIR = '../experiments/ml_experiments'
Path(RESULTS_DIR).mkdir(parents=True, exist_ok=True)

# Models to compare
MODELS_TO_TEST = ['XGBoost', 'LightGBM', 'RandomForest', 'LogisticRegression']

# Segment weights for weighted metrics (higher = more important)
SEGMENT_WEIGHTS = {
    '1 Order': 0.5,
    '2-4 Orders': 1,
    '5-10 Orders': 1.5,
    '11-30 Orders': 4,
    '30+ Orders': 8
}

# Imbalanced segments (need class weighting)
IMBALANCED_SEGMENTS = ['1 Order', '30+ Orders']

print('📋 Configuration:')
print(f'   Models: {MODELS_TO_TEST}')
print(f'   Segment Weights: {SEGMENT_WEIGHTS}')
print(f'   Imbalanced Segments: {IMBALANCED_SEGMENTS}')
# Out:
# 📋 Configuration:
#    Models: ['XGBoost', 'LightGBM', 'RandomForest', 'LogisticRegression']
#    Segment Weights: {'1 Order': 0.5, '2-4 Orders': 1, '5-10 Orders': 1.5, '11-30 Orders': 4, '30+ Orders': 8}
#    Imbalanced Segments: ['1 Order', '30+ Orders']

# %% [markdown]
# ## 1️⃣ Load Data

# %%
print('📂 Loading data...')

train_df = pd.read_csv(f'{DATA_DIR}/train_features.csv')
test_df = pd.read_csv(f'{DATA_DIR}/test_features.csv')

with open(f'{DATA_DIR}/feature_columns.txt', 'r') as f:
    feature_cols = [line.strip() for line in f.readlines()]

print(f'   Train: {len(train_df):,} users')
print(f'   Test:  {len(test_df):,} users')
print(f'   Features: {len(feature_cols)}')

# Show segment distribution
fig = plot_segment_distribution(train_df, 'frequency_segment', 'is_churned')
plt.suptitle('Training Data Distribution', fontsize=14, fontweight='bold')
plt.show()
# Out:
# 📂 Loading data...
#    Train: 265,962 users
#    Test:  261,889 users
#    Features: 98

# %%
# Encode categorical features
label_encoders = {}
categorical_cols = [col for col in feature_cols 
                    if col in train_df.columns and train_df[col].dtype == 'object']

for col in categorical_cols:
    le = LabelEncoder()
    combined = pd.concat([train_df[col], test_df[col]]).astype(str)
    le.fit(combined)
    train_df[col] = le.transform(train_df[col].astype(str))
    test_df[col] = le.transform(test_df[col].astype(str))
    label_encoders[col] = le

print(f'Encoded: {categorical_cols}')
# Out:
# Encoded: []

# %%
# Prepare data
X_train_full = train_df[feature_cols].fillna(0)
y_train_full = train_df['is_churned']
segments_train_full = train_df['frequency_segment']

X_test_full = test_df[feature_cols].fillna(0)
y_test_full = test_df['is_churned']
segments_test_full = test_df['frequency_segment']

# Get segment list
SEGMENTS = sorted(train_df['frequency_segment'].unique().tolist())
print(f'Segments: {SEGMENTS}')
# Out:
# Segments: ['1 Order', '11-30 Orders', '2-4 Orders', '30+ Orders', '5-10 Orders']

# %% [markdown]
# ## 2️⃣ Experiment 1: Rule-Based Baseline
#
# **قانون ساده:** اگر از آخرین خرید بیشتر از threshold روز گذشته → Churn

# %%
print('='*80)
print('📏 EXPERIMENT 1: Rule-Based Baseline')
print('='*80)

# Rule-based model with segment-specific thresholds
rule_based = RuleBasedBaseline(thresholds={
    '1 Order': 45,
    '2-4 Orders': 60,
    '5-10 Orders': 30,
    '11-30 Orders': 20,
    '30+ Orders': 14
})

print(f'\nThresholds: {rule_based.get_thresholds()}')

# Predict using recency feature
recency_test = test_df['recency'].values

y_pred_baseline = rule_based.predict(recency_test, segments_test_full.values)
y_prob_baseline = rule_based.predict_proba(recency_test, segments_test_full.values)

# Calculate per-segment metrics
baseline_segment_metrics = {}
for segment in SEGMENTS:
    mask = segments_test_full == segment
    y_true_seg = y_test_full[mask]
    y_pred_seg = y_pred_baseline[mask]
    y_prob_seg = y_prob_baseline[mask]
    
    baseline_segment_metrics[segment] = {
        'recall': recall_score(y_true_seg, y_pred_seg, zero_division=0),
        'precision': precision_score(y_true_seg, y_pred_seg, zero_division=0),
        'f1': f1_score(y_true_seg, y_pred_seg, zero_division=0),
        'roc_auc': roc_auc_score(y_true_seg, y_prob_seg) if len(np.unique(y_true_seg)) > 1 else 0,
        'support': len(y_true_seg)
    }

baseline_weighted_recall = print_segment_results(
    baseline_segment_metrics, SEGMENT_WEIGHTS, '📊 Rule-Based Baseline Results:'
)
# Out:
# ================================================================================
# 📏 EXPERIMENT 1: Rule-Based Baseline
# ================================================================================
#
# Thresholds: {'1 Order': 45, '2-4 Orders': 60, '5-10 Orders': 30, '11-30 Orders': 20, '30+ Orders': 14}
#
# 📊 Rule-Based Baseline Results:
# ----------------------------------------------------------------------
# Segment                  Recall  Precision         F1        AUC
# ----------------------------------------------------------------------
# 1 Order                  0.6472     0.8659     0.7407     0.5657
# 11-30 Orders             0.6327     0.4355     0.5159     0.6784
# 2-4 Orders               0.2886     0.5932     0.3883     0.5940
# 30+ Orders               0.5491     0.4481     0.4935     0.7958
# 5-10 Orders              0.5720     0.4715     0.5169     0.6217
# ----------------------------------------------------------------------
# WEIGHTED RECALL          0.5596

# %% [markdown]
# ## 3️⃣ Experiment 2: Per-Segment vs Unified Model
#
# **مقایسه:**
# - **Per-Segment:** 5 مدل XGBoost جداگانه
# - **Unified:** 1 مدل XGBoost روی کل داده

# %%
print('='*80)
print('🔀 EXPERIMENT 2: Per-Segment vs Unified Model')
print('='*80)
# Out:
# ================================================================================
# 🔀 EXPERIMENT 2: Per-Segment vs Unified Model
# ================================================================================

# %%
# 2A: Per-Segment Models
print('\n📊 A) Training Per-Segment XGBoost Models...')

per_segment_result = train_per_segment_models(
    model_name='XGBoost',
    segments=SEGMENTS,
    X_train=X_train_full,
    y_train=y_train_full,
    segments_train=segments_train_full,
    X_test=X_test_full,
    y_test=y_test_full,
    segments_test=segments_test_full,
    imbalanced_segments=IMBALANCED_SEGMENTS
)

per_segment_weighted_recall = print_segment_results(
    per_segment_result['segment_metrics'], SEGMENT_WEIGHTS, '📊 Per-Segment XGBoost Results:'
)
# Out:
# 📊 A) Training Per-Segment XGBoost Models...
# [0]	validation_0-aucpr:0.91969
# [1]	validation_0-aucpr:0.92014
# [2]	validation_0-aucpr:0.92070
# [3]	validation_0-aucpr:0.92113
# [4]	validation_0-aucpr:0.92124
# [5]	validation_0-aucpr:0.92134
# [6]	validation_0-aucpr:0.92131
# [7]	validation_0-aucpr:0.92121
# [8]	validation_0-aucpr:0.92151
# [9]	validation_0-aucpr:0.92124
# [10]	validation_0-aucpr:0.92126
# [11]	validation_0-aucpr:0.92140
# [12]	validation_0-aucpr:0.92140
# [13]	validation_0-aucpr:0.92138
# [14]	validation_0-aucpr:0.92136
# [15]	validation_0-aucpr:0.92161
# [16]	validation_0-aucpr:0.92156
# [17]	validation_0-aucpr:0.92159
# [18]	validation_0-aucpr:0.92161
# [19]	validation_0-aucpr:0.92158
# [20]	validation_0-aucpr:0.92155
# [21]	validation_0-aucpr:0.92164
# [22]	validation_0-aucpr:0.92178
# [23]	validation_0-aucpr:0.92199
# [24]	validation_0-aucpr:0.92194
# [25]	validation_0-aucpr:0.92189
# [26]	validation_0-aucpr:0.92185
# [27]	validation_0-aucpr:0.92190
# [28]	validation_0-aucpr:0.92187
# [29]	validation_0-aucpr:0.92189
# [30]	validation_0-aucpr:0.92188
# [31]	validation_0-aucpr:0.92181
# [32]	validation_0-aucpr:0.92176
# [33]	validation_0-aucpr:0.92185
# [34]	validation_0-aucpr:0.92185
# [35]	validation_0-aucpr:0.92192
# [36]	validation_0-aucpr:0.92183
# [37]	validation_0-aucpr:0.92183
# [38]	validation_0-aucpr:0.92175
# [39]	validation_0-aucpr:0.92178
# [40]	validation_0-aucpr:0.92185
# [41]	validation_0-aucpr:0.92182
# [42]	validation_0-aucpr:0.92183
# [43]	validation_0-aucpr:0.92181
# [44]	validation_0-aucpr:0.92179
# [45]	validation_0-aucpr:0.92182
# [46]	validation_0-aucpr:0.92182
# [47]	validation_0-aucpr:0.92193
# [48]	validation_0-aucpr:0.92200
# [49]	validation_0-aucpr:0.92195
# [50]	validation_0-aucpr:0.92197
# [51]	validation_0-aucpr:0.92195
# [52]	validation_0-aucpr:0.92193
# [53]	validation_0-aucpr:0.92196
# [54]	validation_0-aucpr:0.92207
# [55]	validation_0-aucpr:0.92208
# [56]	validation_0-aucpr:0.92206
# [57]	validation_0-aucpr:0.92204
# [58]	validation_0-aucpr:0.92205
# [59]	validation_0-aucpr:0.92203
# [60]	validation_0-aucpr:0.92202
# [61]	validation_0-aucpr:0.92191
# [62]	validation_0-aucpr:0.92198
# [63]	validation_0-aucpr:0.92201
# [64]	validation_0-aucpr:0.92204
# [65]	validation_0-aucpr:0.92200
# [66]	validation_0-aucpr:0.92200
# [67]	validation_0-aucpr:0.92198
# [68]	validation_0-aucpr:0.92198
# [69]	validation_0-aucpr:0.92204
# [70]	validation_0-aucpr:0.92204
# [71]	validation_0-aucpr:0.92205
# [72]	validation_0-aucpr:0.92198
# [73]	validation_0-aucpr:0.92199
# [74]	validation_0-aucpr:0.92202
# [75]	validation_0-aucpr:0.92201
# [76]	validation_0-aucpr:0.92206
# [77]	validation_0-aucpr:0.92207
# [78]	validation_0-aucpr:0.92213
# [79]	validation_0-aucpr:0.92210
# [80]	validation_0-aucpr:0.92209
# [81]	validation_0-aucpr:0.92203
# [82]	validation_0-aucpr:0.92201
# [83]	validation_0-aucpr:0.92202
# [84]	validation_0-aucpr:0.92203
# [85]	validation_0-aucpr:0.92199
# [86]	validation_0-aucpr:0.92194
# [87]	validation_0-aucpr:0.92193
# [88]	validation_0-aucpr:0.92191
# [89]	validation_0-aucpr:0.92184
# [90]	validation_0-aucpr:0.92180
# [91]	validation_0-aucpr:0.92178
# [92]	validation_0-aucpr:0.92176
# [93]	validation_0-aucpr:0.92165
# [94]	validation_0-aucpr:0.92168
# [95]	validation_0-aucpr:0.92166
# [96]	validation_0-aucpr:0.92172
# [97]	validation_0-aucpr:0.92168
# [98]	validation_0-aucpr:0.92169
# [99]	validation_0-aucpr:0.92166
# [100]	validation_0-aucpr:0.92168
# [101]	validation_0-aucpr:0.92169
# [102]	validation_0-aucpr:0.92171
# [103]	validation_0-aucpr:0.92171
# [104]	validation_0-aucpr:0.92169
# [105]	validation_0-aucpr:0.92164
# [106]	validation_0-aucpr:0.92164
# [107]	validation_0-aucpr:0.92165
# [108]	validation_0-aucpr:0.92165
# [109]	validation_0-aucpr:0.92164
# [110]	validation_0-aucpr:0.92161
# [111]	validation_0-aucpr:0.92162
# [112]	validation_0-aucpr:0.92162
# [113]	validation_0-aucpr:0.92162
# [114]	validation_0-aucpr:0.92160
# [115]	validation_0-aucpr:0.92157
# [116]	validation_0-aucpr:0.92152
# [117]	validation_0-aucpr:0.92155
# [118]	validation_0-aucpr:0.92167
# [119]	validation_0-aucpr:0.92171
# [120]	validation_0-aucpr:0.92166
# [121]	validation_0-aucpr:0.92167
# [122]	validation_0-aucpr:0.92167
# [123]	validation_0-aucpr:0.92168
# [124]	validation_0-aucpr:0.92165
# [125]	validation_0-aucpr:0.92167
# [126]	validation_0-aucpr:0.92159
# [127]	validation_0-aucpr:0.92159
# [128]	validation_0-aucpr:0.92160
# [129]	validation_0-aucpr:0.92159
# [130]	validation_0-aucpr:0.92158
# [131]	validation_0-aucpr:0.92166
# [132]	validation_0-aucpr:0.92165
# [133]	validation_0-aucpr:0.92166
# [134]	validation_0-aucpr:0.92164
# [135]	validation_0-aucpr:0.92161
# [136]	validation_0-aucpr:0.92161
# [137]	validation_0-aucpr:0.92161
# [138]	validation_0-aucpr:0.92158
# [139]	validation_0-aucpr:0.92154
# [140]	validation_0-aucpr:0.92152
# [141]	validation_0-aucpr:0.92151
# [142]	validation_0-aucpr:0.92152
# [143]	validation_0-aucpr:0.92150
# [144]	validation_0-aucpr:0.92148
# [145]	validation_0-aucpr:0.92153
# [146]	validation_0-aucpr:0.92152
# [147]	validation_0-aucpr:0.92153
# [148]	validation_0-aucpr:0.92154
# [149]	validation_0-aucpr:0.92154
# [150]	validation_0-aucpr:0.92153
# [151]	validation_0-aucpr:0.92153
# [152]	validation_0-aucpr:0.92151
# [153]	validation_0-aucpr:0.92151
# [154]	validation_0-aucpr:0.92148
# [155]	validation_0-aucpr:0.92150
# [156]	validation_0-aucpr:0.92152
# [157]	validation_0-aucpr:0.92150
# [158]	validation_0-aucpr:0.92150
# [159]	validation_0-aucpr:0.92150
# [160]	validation_0-aucpr:0.92150
# [161]	validation_0-aucpr:0.92150
# [162]	validation_0-aucpr:0.92149
# [163]	validation_0-aucpr:0.92144
# [164]	validation_0-aucpr:0.92146
# [165]	validation_0-aucpr:0.92143
# [166]	validation_0-aucpr:0.92144
# [167]	validation_0-aucpr:0.92144
# [168]	validation_0-aucpr:0.92143
# [169]	validation_0-aucpr:0.92140
# [170]	validation_0-aucpr:0.92140
# [171]	validation_0-aucpr:0.92137
# [172]	validation_0-aucpr:0.92136
# [173]	validation_0-aucpr:0.92137
# [174]	validation_0-aucpr:0.92132
# [175]	validation_0-aucpr:0.92131
# [176]	validation_0-aucpr:0.92126
# [177]	validation_0-aucpr:0.92125
# [178]	validation_0-aucpr:0.92126
# [179]	validation_0-aucpr:0.92125
# [180]	validation_0-aucpr:0.92124
# [181]	validation_0-aucpr:0.92123
# [182]	validation_0-aucpr:0.92120
# [183]	validation_0-aucpr:0.92120
# [184]	validation_0-aucpr:0.92119
# [185]	validation_0-aucpr:0.92116
# [186]	validation_0-aucpr:0.92112
# [187]	validation_0-aucpr:0.92112
# [188]	validation_0-aucpr:0.92113
# [189]	validation_0-aucpr:0.92113
# [190]	validation_0-aucpr:0.92114
# [191]	validation_0-aucpr:0.92114
# [192]	validation_0-aucpr:0.92112
# [193]	validation_0-aucpr:0.92107
# [194]	validation_0-aucpr:0.92106
# [195]	validation_0-aucpr:0.92105
# [196]	validation_0-aucpr:0.92105
# [197]	validation_0-aucpr:0.92106
# [198]	validation_0-aucpr:0.92104
# [199]	validation_0-aucpr:0.92104
# [200]	validation_0-aucpr:0.92102
# [201]	validation_0-aucpr:0.92101
# [202]	validation_0-aucpr:0.92101
# [203]	validation_0-aucpr:0.92101
# [204]	validation_0-aucpr:0.92100
# [205]	validation_0-aucpr:0.92099
# [206]	validation_0-aucpr:0.92099
# [207]	validation_0-aucpr:0.92097
# [208]	validation_0-aucpr:0.92098
# [209]	validation_0-aucpr:0.92094
# [210]	validation_0-aucpr:0.92094
# [211]	validation_0-aucpr:0.92094
# [212]	validation_0-aucpr:0.92094
# [213]	validation_0-aucpr:0.92094
# [214]	validation_0-aucpr:0.92094
# [215]	validation_0-aucpr:0.92094
# [216]	validation_0-aucpr:0.92093
# [217]	validation_0-aucpr:0.92093
# [218]	validation_0-aucpr:0.92093
# [219]	validation_0-aucpr:0.92092
# [220]	validation_0-aucpr:0.92093
# [221]	validation_0-aucpr:0.92093
# [222]	validation_0-aucpr:0.92093
# [223]	validation_0-aucpr:0.92092
# [224]	validation_0-aucpr:0.92092
# [225]	validation_0-aucpr:0.92091
# [226]	validation_0-aucpr:0.92092
# [227]	validation_0-aucpr:0.92092
# [228]	validation_0-aucpr:0.92091
# [229]	validation_0-aucpr:0.92087
# [230]	validation_0-aucpr:0.92087
# [231]	validation_0-aucpr:0.92086
# [232]	validation_0-aucpr:0.92084
# [233]	validation_0-aucpr:0.92084
# [234]	validation_0-aucpr:0.92084
# [235]	validation_0-aucpr:0.92079
# [236]	validation_0-aucpr:0.92079
# [237]	validation_0-aucpr:0.92079
# [238]	validation_0-aucpr:0.92079
# [239]	validation_0-aucpr:0.92079
# [240]	validation_0-aucpr:0.92075
# [241]	validation_0-aucpr:0.92073
# [242]	validation_0-aucpr:0.92072
# [243]	validation_0-aucpr:0.92071
# [244]	validation_0-aucpr:0.92071
# [245]	validation_0-aucpr:0.92070
# [246]	validation_0-aucpr:0.92068
# [247]	validation_0-aucpr:0.92068
# [248]	validation_0-aucpr:0.92066
# [249]	validation_0-aucpr:0.92065
# [250]	validation_0-aucpr:0.92065
# [251]	validation_0-aucpr:0.92064
# [252]	validation_0-aucpr:0.92058
# [253]	validation_0-aucpr:0.92058
# [254]	validation_0-aucpr:0.92058
# [255]	validation_0-aucpr:0.92057
# [256]	validation_0-aucpr:0.92056
# [257]	validation_0-aucpr:0.92055
# [258]	validation_0-aucpr:0.92055
# [259]	validation_0-aucpr:0.92055
# [260]	validation_0-aucpr:0.92054
# [261]	validation_0-aucpr:0.92054
# [262]	validation_0-aucpr:0.92055
# [263]	validation_0-aucpr:0.92054
# [264]	validation_0-aucpr:0.92052
# [265]	validation_0-aucpr:0.92055
# [266]	validation_0-aucpr:0.92053
# [267]	validation_0-aucpr:0.92053
# [268]	validation_0-aucpr:0.92052
# [269]	validation_0-aucpr:0.92051
# [270]	validation_0-aucpr:0.92053
# [271]	validation_0-aucpr:0.92053
# [272]	validation_0-aucpr:0.92053
# [273]	validation_0-aucpr:0.92052
# [274]	validation_0-aucpr:0.92051
# [275]	validation_0-aucpr:0.92043
# [276]	validation_0-aucpr:0.92042
# [277]	validation_0-aucpr:0.92043
# [0]	validation_0-aucpr:0.47191
# [1]	validation_0-aucpr:0.48855
# [2]	validation_0-aucpr:0.49572
# [3]	validation_0-aucpr:0.49843
# [4]	validation_0-aucpr:0.49854
# [5]	validation_0-aucpr:0.50107
# [6]	validation_0-aucpr:0.50170
# [7]	validation_0-aucpr:0.50334
# [8]	validation_0-aucpr:0.50330
# [9]	validation_0-aucpr:0.50331
# [10]	validation_0-aucpr:0.50422
# [11]	validation_0-aucpr:0.50435
# [12]	validation_0-aucpr:0.50544
# [13]	validation_0-aucpr:0.50585
# [14]	validation_0-aucpr:0.50569
# [15]	validation_0-aucpr:0.50631
# [16]	validation_0-aucpr:0.50651
# [17]	validation_0-aucpr:0.50697
# [18]	validation_0-aucpr:0.50748
# [19]	validation_0-aucpr:0.50773
# [20]	validation_0-aucpr:0.50842
# [21]	validation_0-aucpr:0.50879
# [22]	validation_0-aucpr:0.50929
# [23]	validation_0-aucpr:0.51085
# [24]	validation_0-aucpr:0.51073
# [25]	validation_0-aucpr:0.51093
# [26]	validation_0-aucpr:0.51119
# [27]	validation_0-aucpr:0.51180
# [28]	validation_0-aucpr:0.51184
# [29]	validation_0-aucpr:0.51257
# [30]	validation_0-aucpr:0.51299
# [31]	validation_0-aucpr:0.51360
# [32]	validation_0-aucpr:0.51374
# [33]	validation_0-aucpr:0.51422
# [34]	validation_0-aucpr:0.51427
# [35]	validation_0-aucpr:0.51499
# [36]	validation_0-aucpr:0.51545
# [37]	validation_0-aucpr:0.51563
# [38]	validation_0-aucpr:0.51556
# [39]	validation_0-aucpr:0.51604
# [40]	validation_0-aucpr:0.51560
# [41]	validation_0-aucpr:0.51574
# [42]	validation_0-aucpr:0.51591
# [43]	validation_0-aucpr:0.51625
# [44]	validation_0-aucpr:0.51643
# [45]	validation_0-aucpr:0.51666
# [46]	validation_0-aucpr:0.51679
# [47]	validation_0-aucpr:0.51770
# [48]	validation_0-aucpr:0.51805
# [49]	validation_0-aucpr:0.51831
# [50]	validation_0-aucpr:0.51880
# [51]	validation_0-aucpr:0.51884
# [52]	validation_0-aucpr:0.51886
# [53]	validation_0-aucpr:0.51884
# [54]	validation_0-aucpr:0.51916
# [55]	validation_0-aucpr:0.51947
# [56]	validation_0-aucpr:0.51974
# [57]	validation_0-aucpr:0.51996
# [58]	validation_0-aucpr:0.52017
# [59]	validation_0-aucpr:0.52037
# [60]	validation_0-aucpr:0.52051
# [61]	validation_0-aucpr:0.52072
# [62]	validation_0-aucpr:0.52067
# [63]	validation_0-aucpr:0.52089
# [64]	validation_0-aucpr:0.52109
# [65]	validation_0-aucpr:0.52115
# [66]	validation_0-aucpr:0.52123
# [67]	validation_0-aucpr:0.52172
# [68]	validation_0-aucpr:0.52222
# [69]	validation_0-aucpr:0.52259
# [70]	validation_0-aucpr:0.52282
# [71]	validation_0-aucpr:0.52314
# [72]	validation_0-aucpr:0.52338
# [73]	validation_0-aucpr:0.52378
# [74]	validation_0-aucpr:0.52405
# [75]	validation_0-aucpr:0.52425
# [76]	validation_0-aucpr:0.52452
# [77]	validation_0-aucpr:0.52474
# [78]	validation_0-aucpr:0.52500
# [79]	validation_0-aucpr:0.52507
# [80]	validation_0-aucpr:0.52518
# [81]	validation_0-aucpr:0.52540
# [82]	validation_0-aucpr:0.52547
# [83]	validation_0-aucpr:0.52587
# [84]	validation_0-aucpr:0.52598
# [85]	validation_0-aucpr:0.52610
# [86]	validation_0-aucpr:0.52622
# [87]	validation_0-aucpr:0.52647
# [88]	validation_0-aucpr:0.52690
# [89]	validation_0-aucpr:0.52708
# [90]	validation_0-aucpr:0.52750
# [91]	validation_0-aucpr:0.52775
# [92]	validation_0-aucpr:0.52807
# [93]	validation_0-aucpr:0.52834
# [94]	validation_0-aucpr:0.52872
# [95]	validation_0-aucpr:0.52905
# [96]	validation_0-aucpr:0.52921
# [97]	validation_0-aucpr:0.52932
# [98]	validation_0-aucpr:0.52940
# [99]	validation_0-aucpr:0.52977
# [100]	validation_0-aucpr:0.53019
# [101]	validation_0-aucpr:0.53083
# [102]	validation_0-aucpr:0.53119
# [103]	validation_0-aucpr:0.53146
# [104]	validation_0-aucpr:0.53140
# [105]	validation_0-aucpr:0.53176
# [106]	validation_0-aucpr:0.53210
# [107]	validation_0-aucpr:0.53231
# [108]	validation_0-aucpr:0.53274
# [109]	validation_0-aucpr:0.53275
# [110]	validation_0-aucpr:0.53310
# [111]	validation_0-aucpr:0.53334
# [112]	validation_0-aucpr:0.53367
# [113]	validation_0-aucpr:0.53380
# [114]	validation_0-aucpr:0.53404
# [115]	validation_0-aucpr:0.53412
# [116]	validation_0-aucpr:0.53411
# [117]	validation_0-aucpr:0.53429
# [118]	validation_0-aucpr:0.53460
# [119]	validation_0-aucpr:0.53487
# [120]	validation_0-aucpr:0.53501
# [121]	validation_0-aucpr:0.53536
# [122]	validation_0-aucpr:0.53552
# [123]	validation_0-aucpr:0.53588
# [124]	validation_0-aucpr:0.53594
# [125]	validation_0-aucpr:0.53632
# [126]	validation_0-aucpr:0.53638
# [127]	validation_0-aucpr:0.53642
# [128]	validation_0-aucpr:0.53655
# [129]	validation_0-aucpr:0.53676
# [130]	validation_0-aucpr:0.53713
# [131]	validation_0-aucpr:0.53725
# [132]	validation_0-aucpr:0.53742
# [133]	validation_0-aucpr:0.53766
# [134]	validation_0-aucpr:0.53764
# [135]	validation_0-aucpr:0.53788
# [136]	validation_0-aucpr:0.53808
# [137]	validation_0-aucpr:0.53834
# [138]	validation_0-aucpr:0.53828
# [139]	validation_0-aucpr:0.53864
# [140]	validation_0-aucpr:0.53922
# [141]	validation_0-aucpr:0.53945
# [142]	validation_0-aucpr:0.53969
# [143]	validation_0-aucpr:0.54031
# [144]	validation_0-aucpr:0.54048
# [145]	validation_0-aucpr:0.54085
# [146]	validation_0-aucpr:0.54098
# [147]	validation_0-aucpr:0.54118
# [148]	validation_0-aucpr:0.54125
# [149]	validation_0-aucpr:0.54119
# [150]	validation_0-aucpr:0.54134
# [151]	validation_0-aucpr:0.54182
# [152]	validation_0-aucpr:0.54223
# [153]	validation_0-aucpr:0.54271
# [154]	validation_0-aucpr:0.54291
# [155]	validation_0-aucpr:0.54318
# [156]	validation_0-aucpr:0.54343
# [157]	validation_0-aucpr:0.54375
# [158]	validation_0-aucpr:0.54404
# [159]	validation_0-aucpr:0.54413
# [160]	validation_0-aucpr:0.54471
# [161]	validation_0-aucpr:0.54498
# [162]	validation_0-aucpr:0.54528
# [163]	validation_0-aucpr:0.54567
# [164]	validation_0-aucpr:0.54608
# [165]	validation_0-aucpr:0.54627
# [166]	validation_0-aucpr:0.54634
# [167]	validation_0-aucpr:0.54640
# [168]	validation_0-aucpr:0.54700
# [169]	validation_0-aucpr:0.54707
# [170]	validation_0-aucpr:0.54746
# [171]	validation_0-aucpr:0.54772
# [172]	validation_0-aucpr:0.54812
# [173]	validation_0-aucpr:0.54819
# [174]	validation_0-aucpr:0.54842
# [175]	validation_0-aucpr:0.54863
# [176]	validation_0-aucpr:0.54882
# [177]	validation_0-aucpr:0.54941
# [178]	validation_0-aucpr:0.54974
# [179]	validation_0-aucpr:0.54982
# [180]	validation_0-aucpr:0.55026
# [181]	validation_0-aucpr:0.55059
# [182]	validation_0-aucpr:0.55084
# [183]	validation_0-aucpr:0.55107
# [184]	validation_0-aucpr:0.55131
# [185]	validation_0-aucpr:0.55155
# [186]	validation_0-aucpr:0.55184
# [187]	validation_0-aucpr:0.55196
# [188]	validation_0-aucpr:0.55226
# [189]	validation_0-aucpr:0.55263
# [190]	validation_0-aucpr:0.55291
# [191]	validation_0-aucpr:0.55313
# [192]	validation_0-aucpr:0.55330
# [193]	validation_0-aucpr:0.55341
# [194]	validation_0-aucpr:0.55351
# [195]	validation_0-aucpr:0.55394
# [196]	validation_0-aucpr:0.55420
# [197]	validation_0-aucpr:0.55437
# [198]	validation_0-aucpr:0.55462
# [199]	validation_0-aucpr:0.55493
# [200]	validation_0-aucpr:0.55501
# [201]	validation_0-aucpr:0.55526
# [202]	validation_0-aucpr:0.55540
# [203]	validation_0-aucpr:0.55583
# [204]	validation_0-aucpr:0.55618
# [205]	validation_0-aucpr:0.55635
# [206]	validation_0-aucpr:0.55643
# [207]	validation_0-aucpr:0.55668
# [208]	validation_0-aucpr:0.55674
# [209]	validation_0-aucpr:0.55715
# [210]	validation_0-aucpr:0.55728
# [211]	validation_0-aucpr:0.55742
# [212]	validation_0-aucpr:0.55761
# [213]	validation_0-aucpr:0.55779
# [214]	validation_0-aucpr:0.55824
# [215]	validation_0-aucpr:0.55868
# [216]	validation_0-aucpr:0.55910
# [217]	validation_0-aucpr:0.55931
# [218]	validation_0-aucpr:0.55960
# [219]	validation_0-aucpr:0.55972
# [220]	validation_0-aucpr:0.55985
# [221]	validation_0-aucpr:0.56003
# [222]	validation_0-aucpr:0.56037
# [223]	validation_0-aucpr:0.56048
# [224]	validation_0-aucpr:0.56057
# [225]	validation_0-aucpr:0.56090
# [226]	validation_0-aucpr:0.56101
# [227]	validation_0-aucpr:0.56120
# [228]	validation_0-aucpr:0.56130
# [229]	validation_0-aucpr:0.56153
# [230]	validation_0-aucpr:0.56159
# [231]	validation_0-aucpr:0.56196
# [232]	validation_0-aucpr:0.56218
# [233]	validation_0-aucpr:0.56239
# [234]	validation_0-aucpr:0.56275
# [235]	validation_0-aucpr:0.56300
# [236]	validation_0-aucpr:0.56320
# [237]	validation_0-aucpr:0.56353
# [238]	validation_0-aucpr:0.56374
# [239]	validation_0-aucpr:0.56396
# [240]	validation_0-aucpr:0.56430
# [241]	validation_0-aucpr:0.56468
# [242]	validation_0-aucpr:0.56471
# [243]	validation_0-aucpr:0.56505
# [244]	validation_0-aucpr:0.56519
# [245]	validation_0-aucpr:0.56528
# [246]	validation_0-aucpr:0.56541
# [247]	validation_0-aucpr:0.56569
# [248]	validation_0-aucpr:0.56584
# [249]	validation_0-aucpr:0.56621
# [250]	validation_0-aucpr:0.56646
# [251]	validation_0-aucpr:0.56664
# [252]	validation_0-aucpr:0.56700
# [253]	validation_0-aucpr:0.56713
# [254]	validation_0-aucpr:0.56746
# [255]	validation_0-aucpr:0.56769
# [256]	validation_0-aucpr:0.56783
# [257]	validation_0-aucpr:0.56810
# [258]	validation_0-aucpr:0.56824
# [259]	validation_0-aucpr:0.56850
# [260]	validation_0-aucpr:0.56866
# [261]	validation_0-aucpr:0.56882
# [262]	validation_0-aucpr:0.56906
# [263]	validation_0-aucpr:0.56919
# [264]	validation_0-aucpr:0.56941
# [265]	validation_0-aucpr:0.56967
# [266]	validation_0-aucpr:0.57007
# [267]	validation_0-aucpr:0.57037
# [268]	validation_0-aucpr:0.57065
# [269]	validation_0-aucpr:0.57106
# [270]	validation_0-aucpr:0.57113
# [271]	validation_0-aucpr:0.57121
# [272]	validation_0-aucpr:0.57136
# [273]	validation_0-aucpr:0.57147
# [274]	validation_0-aucpr:0.57153
# [275]	validation_0-aucpr:0.57163
# [276]	validation_0-aucpr:0.57188
# [277]	validation_0-aucpr:0.57195
# [278]	validation_0-aucpr:0.57217
# [279]	validation_0-aucpr:0.57231
# [280]	validation_0-aucpr:0.57264
# [281]	validation_0-aucpr:0.57275
# [282]	validation_0-aucpr:0.57298
# [283]	validation_0-aucpr:0.57313
# [284]	validation_0-aucpr:0.57309
# [285]	validation_0-aucpr:0.57335
# [286]	validation_0-aucpr:0.57367
# [287]	validation_0-aucpr:0.57362
# [288]	validation_0-aucpr:0.57382
# [289]	validation_0-aucpr:0.57411
# [290]	validation_0-aucpr:0.57447
# [291]	validation_0-aucpr:0.57463
# [292]	validation_0-aucpr:0.57477
# [293]	validation_0-aucpr:0.57499
# [294]	validation_0-aucpr:0.57516
# [295]	validation_0-aucpr:0.57532
# [296]	validation_0-aucpr:0.57535
# [297]	validation_0-aucpr:0.57556
# [298]	validation_0-aucpr:0.57572
# [299]	validation_0-aucpr:0.57578
# [300]	validation_0-aucpr:0.57608
# [301]	validation_0-aucpr:0.57655
# [302]	validation_0-aucpr:0.57665
# [303]	validation_0-aucpr:0.57690
# [304]	validation_0-aucpr:0.57701
# [305]	validation_0-aucpr:0.57702
# [306]	validation_0-aucpr:0.57718
# [307]	validation_0-aucpr:0.57723
# [308]	validation_0-aucpr:0.57735
# [309]	validation_0-aucpr:0.57738
# [310]	validation_0-aucpr:0.57759
# [311]	validation_0-aucpr:0.57775
# [312]	validation_0-aucpr:0.57797
# [313]	validation_0-aucpr:0.57812
# [314]	validation_0-aucpr:0.57849
# [315]	validation_0-aucpr:0.57859
# [316]	validation_0-aucpr:0.57875
# [317]	validation_0-aucpr:0.57889
# [318]	validation_0-aucpr:0.57902
# [319]	validation_0-aucpr:0.57922
# [320]	validation_0-aucpr:0.57950
# [321]	validation_0-aucpr:0.57956
# [322]	validation_0-aucpr:0.57980
# [323]	validation_0-aucpr:0.57990
# [324]	validation_0-aucpr:0.57997
# [325]	validation_0-aucpr:0.58021
# [326]	validation_0-aucpr:0.58063
# [327]	validation_0-aucpr:0.58080
# [328]	validation_0-aucpr:0.58094
# [329]	validation_0-aucpr:0.58128
# [330]	validation_0-aucpr:0.58135
# [331]	validation_0-aucpr:0.58141
# [332]	validation_0-aucpr:0.58158
# [333]	validation_0-aucpr:0.58181
# [334]	validation_0-aucpr:0.58191
# [335]	validation_0-aucpr:0.58202
# [336]	validation_0-aucpr:0.58212
# [337]	validation_0-aucpr:0.58236
# [338]	validation_0-aucpr:0.58265
# [339]	validation_0-aucpr:0.58272
# [340]	validation_0-aucpr:0.58283
# [341]	validation_0-aucpr:0.58305
# [342]	validation_0-aucpr:0.58306
# [343]	validation_0-aucpr:0.58317
# [344]	validation_0-aucpr:0.58319
# [345]	validation_0-aucpr:0.58336
# [346]	validation_0-aucpr:0.58363
# [347]	validation_0-aucpr:0.58401
# [348]	validation_0-aucpr:0.58413
# [349]	validation_0-aucpr:0.58442
# [350]	validation_0-aucpr:0.58463
# [351]	validation_0-aucpr:0.58476
# [352]	validation_0-aucpr:0.58483
# [353]	validation_0-aucpr:0.58498
# [354]	validation_0-aucpr:0.58495
# [355]	validation_0-aucpr:0.58516
# [356]	validation_0-aucpr:0.58522
# [357]	validation_0-aucpr:0.58554
# [358]	validation_0-aucpr:0.58558
# [359]	validation_0-aucpr:0.58575
# [360]	validation_0-aucpr:0.58588
# [361]	validation_0-aucpr:0.58589
# [362]	validation_0-aucpr:0.58598
# [363]	validation_0-aucpr:0.58608
# [364]	validation_0-aucpr:0.58613
# [365]	validation_0-aucpr:0.58614
# [366]	validation_0-aucpr:0.58641
# [367]	validation_0-aucpr:0.58642
# [368]	validation_0-aucpr:0.58655
# [369]	validation_0-aucpr:0.58653
# [370]	validation_0-aucpr:0.58665
# [371]	validation_0-aucpr:0.58666
# [372]	validation_0-aucpr:0.58672
# [373]	validation_0-aucpr:0.58674
# [374]	validation_0-aucpr:0.58689
# [375]	validation_0-aucpr:0.58695
# [376]	validation_0-aucpr:0.58718
# [377]	validation_0-aucpr:0.58721
# [378]	validation_0-aucpr:0.58732
# [379]	validation_0-aucpr:0.58733
# [380]	validation_0-aucpr:0.58756
# [381]	validation_0-aucpr:0.58781
# [382]	validation_0-aucpr:0.58784
# [383]	validation_0-aucpr:0.58798
# [384]	validation_0-aucpr:0.58821
# [385]	validation_0-aucpr:0.58838
# [386]	validation_0-aucpr:0.58856
# [387]	validation_0-aucpr:0.58868
# [388]	validation_0-aucpr:0.58885
# [389]	validation_0-aucpr:0.58893
# [390]	validation_0-aucpr:0.58913
# [391]	validation_0-aucpr:0.58910
# [392]	validation_0-aucpr:0.58916
# [393]	validation_0-aucpr:0.58922
# [394]	validation_0-aucpr:0.58926
# [395]	validation_0-aucpr:0.58948
# [396]	validation_0-aucpr:0.58964
# [397]	validation_0-aucpr:0.58989
# [398]	validation_0-aucpr:0.59005
# [399]	validation_0-aucpr:0.59014
# [400]	validation_0-aucpr:0.59031
# [401]	validation_0-aucpr:0.59048
# [402]	validation_0-aucpr:0.59046
# [403]	validation_0-aucpr:0.59048
# [404]	validation_0-aucpr:0.59074
# [405]	validation_0-aucpr:0.59080
# [406]	validation_0-aucpr:0.59101
# [407]	validation_0-aucpr:0.59122
# [408]	validation_0-aucpr:0.59134
# [409]	validation_0-aucpr:0.59141
# [410]	validation_0-aucpr:0.59143
# [411]	validation_0-aucpr:0.59155
# [412]	validation_0-aucpr:0.59158
# [413]	validation_0-aucpr:0.59171
# [414]	validation_0-aucpr:0.59184
# [415]	validation_0-aucpr:0.59196
# [416]	validation_0-aucpr:0.59199
# [417]	validation_0-aucpr:0.59220
# [418]	validation_0-aucpr:0.59225
# [419]	validation_0-aucpr:0.59233
# [420]	validation_0-aucpr:0.59237
# [421]	validation_0-aucpr:0.59243
# [422]	validation_0-aucpr:0.59260
# [423]	validation_0-aucpr:0.59263
# [424]	validation_0-aucpr:0.59269
# [425]	validation_0-aucpr:0.59291
# [426]	validation_0-aucpr:0.59298
# [427]	validation_0-aucpr:0.59303
# [428]	validation_0-aucpr:0.59322
# [429]	validation_0-aucpr:0.59337
# [430]	validation_0-aucpr:0.59347
# [431]	validation_0-aucpr:0.59358
# [432]	validation_0-aucpr:0.59377
# [433]	validation_0-aucpr:0.59389
# [434]	validation_0-aucpr:0.59400
# [435]	validation_0-aucpr:0.59413
# [436]	validation_0-aucpr:0.59431
# [437]	validation_0-aucpr:0.59446
# [438]	validation_0-aucpr:0.59459
# [439]	validation_0-aucpr:0.59469
# [440]	validation_0-aucpr:0.59476
# [441]	validation_0-aucpr:0.59491
# [442]	validation_0-aucpr:0.59493
# [443]	validation_0-aucpr:0.59497
# [444]	validation_0-aucpr:0.59518
# [445]	validation_0-aucpr:0.59532
# [446]	validation_0-aucpr:0.59536
# [447]	validation_0-aucpr:0.59545
# [448]	validation_0-aucpr:0.59549
# [449]	validation_0-aucpr:0.59553
# [450]	validation_0-aucpr:0.59547
# [451]	validation_0-aucpr:0.59554
# [452]	validation_0-aucpr:0.59572
# [453]	validation_0-aucpr:0.59595
# [454]	validation_0-aucpr:0.59609
# [455]	validation_0-aucpr:0.59640
# [456]	validation_0-aucpr:0.59667
# [457]	validation_0-aucpr:0.59680
# [458]	validation_0-aucpr:0.59702
# [459]	validation_0-aucpr:0.59722
# [460]	validation_0-aucpr:0.59726
# [461]	validation_0-aucpr:0.59737
# [462]	validation_0-aucpr:0.59754
# [463]	validation_0-aucpr:0.59764
# [464]	validation_0-aucpr:0.59769
# [465]	validation_0-aucpr:0.59783
# [466]	validation_0-aucpr:0.59798
# [467]	validation_0-aucpr:0.59808
# [468]	validation_0-aucpr:0.59823
# [469]	validation_0-aucpr:0.59829
# [470]	validation_0-aucpr:0.59830
# [471]	validation_0-aucpr:0.59838
# [472]	validation_0-aucpr:0.59848
# [473]	validation_0-aucpr:0.59864
# [474]	validation_0-aucpr:0.59870
# [475]	validation_0-aucpr:0.59877
# [476]	validation_0-aucpr:0.59898
# [477]	validation_0-aucpr:0.59899
# [478]	validation_0-aucpr:0.59911
# [479]	validation_0-aucpr:0.59911
# [480]	validation_0-aucpr:0.59920
# [481]	validation_0-aucpr:0.59935
# [482]	validation_0-aucpr:0.59942
# [483]	validation_0-aucpr:0.59944
# [484]	validation_0-aucpr:0.59963
# [485]	validation_0-aucpr:0.59971
# [486]	validation_0-aucpr:0.59978
# [487]	validation_0-aucpr:0.59994
# [488]	validation_0-aucpr:0.59991
# [489]	validation_0-aucpr:0.60005
# [490]	validation_0-aucpr:0.60008
# [491]	validation_0-aucpr:0.60021
# [492]	validation_0-aucpr:0.60030
# [493]	validation_0-aucpr:0.60036
# [494]	validation_0-aucpr:0.60043
# [495]	validation_0-aucpr:0.60053
# [496]	validation_0-aucpr:0.60068
# [497]	validation_0-aucpr:0.60082
# [498]	validation_0-aucpr:0.60090
# [499]	validation_0-aucpr:0.60101
# [500]	validation_0-aucpr:0.60115
# [501]	validation_0-aucpr:0.60115
# [502]	validation_0-aucpr:0.60129
# [503]	validation_0-aucpr:0.60137
# [504]	validation_0-aucpr:0.60142
# [505]	validation_0-aucpr:0.60150
# [506]	validation_0-aucpr:0.60162
# [507]	validation_0-aucpr:0.60171
# [508]	validation_0-aucpr:0.60176
# [509]	validation_0-aucpr:0.60182
# [510]	validation_0-aucpr:0.60189
# [511]	validation_0-aucpr:0.60183
# [512]	validation_0-aucpr:0.60179
# [513]	validation_0-aucpr:0.60187
# [514]	validation_0-aucpr:0.60211
# [515]	validation_0-aucpr:0.60215
# [516]	validation_0-aucpr:0.60236
# [517]	validation_0-aucpr:0.60241
# [518]	validation_0-aucpr:0.60254
# [519]	validation_0-aucpr:0.60260
# [520]	validation_0-aucpr:0.60270
# [521]	validation_0-aucpr:0.60280
# [522]	validation_0-aucpr:0.60294
# [523]	validation_0-aucpr:0.60297
# [524]	validation_0-aucpr:0.60318
# [525]	validation_0-aucpr:0.60327
# [526]	validation_0-aucpr:0.60341
# [527]	validation_0-aucpr:0.60353
# [528]	validation_0-aucpr:0.60357
# [529]	validation_0-aucpr:0.60379
# [530]	validation_0-aucpr:0.60388
# [531]	validation_0-aucpr:0.60396
# [532]	validation_0-aucpr:0.60394
# [533]	validation_0-aucpr:0.60405
# [534]	validation_0-aucpr:0.60415
# [535]	validation_0-aucpr:0.60415
# [536]	validation_0-aucpr:0.60430
# [537]	validation_0-aucpr:0.60445
# [538]	validation_0-aucpr:0.60444
# [539]	validation_0-aucpr:0.60465
# [540]	validation_0-aucpr:0.60469
# [541]	validation_0-aucpr:0.60479
# [542]	validation_0-aucpr:0.60495
# [543]	validation_0-aucpr:0.60495
# [544]	validation_0-aucpr:0.60498
# [545]	validation_0-aucpr:0.60508
# [546]	validation_0-aucpr:0.60506
# [547]	validation_0-aucpr:0.60508
# [548]	validation_0-aucpr:0.60504
# [549]	validation_0-aucpr:0.60514
# [550]	validation_0-aucpr:0.60538
# [551]	validation_0-aucpr:0.60545
# [552]	validation_0-aucpr:0.60543
# [553]	validation_0-aucpr:0.60547
# [554]	validation_0-aucpr:0.60540
# [555]	validation_0-aucpr:0.60540
# [556]	validation_0-aucpr:0.60545
# [557]	validation_0-aucpr:0.60558
# [558]	validation_0-aucpr:0.60565
# [559]	validation_0-aucpr:0.60576
# [560]	validation_0-aucpr:0.60578
# [561]	validation_0-aucpr:0.60579
# [562]	validation_0-aucpr:0.60583
# [563]	validation_0-aucpr:0.60599
# [564]	validation_0-aucpr:0.60611
# [565]	validation_0-aucpr:0.60617
# [566]	validation_0-aucpr:0.60638
# [567]	validation_0-aucpr:0.60656
# [568]	validation_0-aucpr:0.60674
# [569]	validation_0-aucpr:0.60676
# [570]	validation_0-aucpr:0.60683
# [571]	validation_0-aucpr:0.60692
# [572]	validation_0-aucpr:0.60705
# [573]	validation_0-aucpr:0.60716
# [574]	validation_0-aucpr:0.60728
# [575]	validation_0-aucpr:0.60735
# [576]	validation_0-aucpr:0.60737
# [577]	validation_0-aucpr:0.60750
# [578]	validation_0-aucpr:0.60759
# [579]	validation_0-aucpr:0.60762
# [580]	validation_0-aucpr:0.60769
# [581]	validation_0-aucpr:0.60778
# [582]	validation_0-aucpr:0.60784
# [583]	validation_0-aucpr:0.60786
# [584]	validation_0-aucpr:0.60789
# [585]	validation_0-aucpr:0.60805
# [586]	validation_0-aucpr:0.60816
# [587]	validation_0-aucpr:0.60814
# [588]	validation_0-aucpr:0.60826
# [589]	validation_0-aucpr:0.60824
# [590]	validation_0-aucpr:0.60827
# [591]	validation_0-aucpr:0.60831
# [592]	validation_0-aucpr:0.60839
# [593]	validation_0-aucpr:0.60854
# [594]	validation_0-aucpr:0.60854
# [595]	validation_0-aucpr:0.60864
# [596]	validation_0-aucpr:0.60872
# [597]	validation_0-aucpr:0.60881
# [598]	validation_0-aucpr:0.60890
# [599]	validation_0-aucpr:0.60894
# [600]	validation_0-aucpr:0.60910
# [601]	validation_0-aucpr:0.60913
# [602]	validation_0-aucpr:0.60929
# [603]	validation_0-aucpr:0.60931
# [604]	validation_0-aucpr:0.60930
# [605]	validation_0-aucpr:0.60936
# [606]	validation_0-aucpr:0.60943
# [607]	validation_0-aucpr:0.60949
# [608]	validation_0-aucpr:0.60957
# [609]	validation_0-aucpr:0.60969
# [610]	validation_0-aucpr:0.60977
# [611]	validation_0-aucpr:0.60990
# [612]	validation_0-aucpr:0.60993
# [613]	validation_0-aucpr:0.60998
# [614]	validation_0-aucpr:0.61005
# [615]	validation_0-aucpr:0.61005
# [616]	validation_0-aucpr:0.61008
# [617]	validation_0-aucpr:0.61014
# [618]	validation_0-aucpr:0.61020
# [619]	validation_0-aucpr:0.61020
# [620]	validation_0-aucpr:0.61029
# [621]	validation_0-aucpr:0.61040
# [622]	validation_0-aucpr:0.61045
# [623]	validation_0-aucpr:0.61053
# [624]	validation_0-aucpr:0.61058
# [625]	validation_0-aucpr:0.61066
# [626]	validation_0-aucpr:0.61074
# [627]	validation_0-aucpr:0.61083
# [628]	validation_0-aucpr:0.61094
# [629]	validation_0-aucpr:0.61093
# [630]	validation_0-aucpr:0.61106
# [631]	validation_0-aucpr:0.61105
# [632]	validation_0-aucpr:0.61113
# [633]	validation_0-aucpr:0.61121
# [634]	validation_0-aucpr:0.61128
# [635]	validation_0-aucpr:0.61141
# [636]	validation_0-aucpr:0.61152
# [637]	validation_0-aucpr:0.61152
# [638]	validation_0-aucpr:0.61163
# [639]	validation_0-aucpr:0.61182
# [640]	validation_0-aucpr:0.61180
# [641]	validation_0-aucpr:0.61193
# [642]	validation_0-aucpr:0.61198
# [643]	validation_0-aucpr:0.61203
# [644]	validation_0-aucpr:0.61207
# [645]	validation_0-aucpr:0.61219
# [646]	validation_0-aucpr:0.61229
# [647]	validation_0-aucpr:0.61227
# [648]	validation_0-aucpr:0.61230
# [649]	validation_0-aucpr:0.61238
# [650]	validation_0-aucpr:0.61249
# [651]	validation_0-aucpr:0.61251
# [652]	validation_0-aucpr:0.61270
# [653]	validation_0-aucpr:0.61266
# [654]	validation_0-aucpr:0.61270
# [655]	validation_0-aucpr:0.61275
# [656]	validation_0-aucpr:0.61283
# [657]	validation_0-aucpr:0.61290
# [658]	validation_0-aucpr:0.61293
# [659]	validation_0-aucpr:0.61306
# [660]	validation_0-aucpr:0.61305
# [661]	validation_0-aucpr:0.61324
# [662]	validation_0-aucpr:0.61329
# [663]	validation_0-aucpr:0.61330
# [664]	validation_0-aucpr:0.61343
# [665]	validation_0-aucpr:0.61352
# [666]	validation_0-aucpr:0.61363
# [667]	validation_0-aucpr:0.61376
# [668]	validation_0-aucpr:0.61379
# [669]	validation_0-aucpr:0.61383
# [670]	validation_0-aucpr:0.61384
# [671]	validation_0-aucpr:0.61381
# [672]	validation_0-aucpr:0.61391
# [673]	validation_0-aucpr:0.61390
# [674]	validation_0-aucpr:0.61402
# [675]	validation_0-aucpr:0.61410
# [676]	validation_0-aucpr:0.61424
# [677]	validation_0-aucpr:0.61429
# [678]	validation_0-aucpr:0.61433
# [679]	validation_0-aucpr:0.61446
# [680]	validation_0-aucpr:0.61445
# [681]	validation_0-aucpr:0.61446
# [682]	validation_0-aucpr:0.61449
# [683]	validation_0-aucpr:0.61456
# [684]	validation_0-aucpr:0.61472
# [685]	validation_0-aucpr:0.61473
# [686]	validation_0-aucpr:0.61473
# [687]	validation_0-aucpr:0.61478
# [688]	validation_0-aucpr:0.61487
# [689]	validation_0-aucpr:0.61494
# [690]	validation_0-aucpr:0.61500
# [691]	validation_0-aucpr:0.61511
# [692]	validation_0-aucpr:0.61516
# [693]	validation_0-aucpr:0.61524
# [694]	validation_0-aucpr:0.61530
# [695]	validation_0-aucpr:0.61538
# [696]	validation_0-aucpr:0.61535
# [697]	validation_0-aucpr:0.61537
# [698]	validation_0-aucpr:0.61544
# [699]	validation_0-aucpr:0.61545
# [700]	validation_0-aucpr:0.61555
# [701]	validation_0-aucpr:0.61562
# [702]	validation_0-aucpr:0.61570
# [703]	validation_0-aucpr:0.61570
# [704]	validation_0-aucpr:0.61578
# [705]	validation_0-aucpr:0.61577
# [706]	validation_0-aucpr:0.61579
# [707]	validation_0-aucpr:0.61589
# [708]	validation_0-aucpr:0.61594
# [709]	validation_0-aucpr:0.61604
# [710]	validation_0-aucpr:0.61610
# [711]	validation_0-aucpr:0.61603
# [712]	validation_0-aucpr:0.61609
# [713]	validation_0-aucpr:0.61613
# [714]	validation_0-aucpr:0.61614
# [715]	validation_0-aucpr:0.61619
# [716]	validation_0-aucpr:0.61614
# [717]	validation_0-aucpr:0.61619
# [718]	validation_0-aucpr:0.61618
# [719]	validation_0-aucpr:0.61633
# [720]	validation_0-aucpr:0.61635
# [721]	validation_0-aucpr:0.61647
# [722]	validation_0-aucpr:0.61654
# [723]	validation_0-aucpr:0.61653
# [724]	validation_0-aucpr:0.61664
# [725]	validation_0-aucpr:0.61665
# [726]	validation_0-aucpr:0.61680
# [727]	validation_0-aucpr:0.61685
# [728]	validation_0-aucpr:0.61687
# [729]	validation_0-aucpr:0.61695
# [730]	validation_0-aucpr:0.61695
# [731]	validation_0-aucpr:0.61700
# [732]	validation_0-aucpr:0.61702
# [733]	validation_0-aucpr:0.61713
# [734]	validation_0-aucpr:0.61717
# [735]	validation_0-aucpr:0.61724
# [736]	validation_0-aucpr:0.61721
# [737]	validation_0-aucpr:0.61724
# [738]	validation_0-aucpr:0.61737
# [739]	validation_0-aucpr:0.61746
# [740]	validation_0-aucpr:0.61744
# [741]	validation_0-aucpr:0.61748
# [742]	validation_0-aucpr:0.61745
# [743]	validation_0-aucpr:0.61754
# [744]	validation_0-aucpr:0.61756
# [745]	validation_0-aucpr:0.61761
# [746]	validation_0-aucpr:0.61757
# [747]	validation_0-aucpr:0.61755
# [748]	validation_0-aucpr:0.61756
# [749]	validation_0-aucpr:0.61756
# [750]	validation_0-aucpr:0.61768
# [751]	validation_0-aucpr:0.61772
# [752]	validation_0-aucpr:0.61779
# [753]	validation_0-aucpr:0.61783
# [754]	validation_0-aucpr:0.61792
# [755]	validation_0-aucpr:0.61793
# [756]	validation_0-aucpr:0.61794
# [757]	validation_0-aucpr:0.61791
# [758]	validation_0-aucpr:0.61797
# [759]	validation_0-aucpr:0.61803
# [760]	validation_0-aucpr:0.61812
# [761]	validation_0-aucpr:0.61813
# [762]	validation_0-aucpr:0.61819
# [763]	validation_0-aucpr:0.61820
# [764]	validation_0-aucpr:0.61822
# [765]	validation_0-aucpr:0.61816
# [766]	validation_0-aucpr:0.61817
# [767]	validation_0-aucpr:0.61820
# [768]	validation_0-aucpr:0.61820
# [769]	validation_0-aucpr:0.61826
# [770]	validation_0-aucpr:0.61834
# [771]	validation_0-aucpr:0.61843
# [772]	validation_0-aucpr:0.61849
# [773]	validation_0-aucpr:0.61845
# [774]	validation_0-aucpr:0.61844
# [775]	validation_0-aucpr:0.61842
# [776]	validation_0-aucpr:0.61847
# [777]	validation_0-aucpr:0.61846
# [778]	validation_0-aucpr:0.61848
# [779]	validation_0-aucpr:0.61847
# [780]	validation_0-aucpr:0.61849
# [781]	validation_0-aucpr:0.61860
# [782]	validation_0-aucpr:0.61861
# [783]	validation_0-aucpr:0.61861
# [784]	validation_0-aucpr:0.61870
# [785]	validation_0-aucpr:0.61874
# [786]	validation_0-aucpr:0.61882
# [787]	validation_0-aucpr:0.61888
# [788]	validation_0-aucpr:0.61893
# [789]	validation_0-aucpr:0.61897
# [790]	validation_0-aucpr:0.61901
# [791]	validation_0-aucpr:0.61905
# [792]	validation_0-aucpr:0.61909
# [793]	validation_0-aucpr:0.61904
# [794]	validation_0-aucpr:0.61901
# [795]	validation_0-aucpr:0.61901
# [796]	validation_0-aucpr:0.61892
# [797]	validation_0-aucpr:0.61902
# [798]	validation_0-aucpr:0.61902
# [799]	validation_0-aucpr:0.61905
# [800]	validation_0-aucpr:0.61904
# [801]	validation_0-aucpr:0.61907
# [802]	validation_0-aucpr:0.61908
# [803]	validation_0-aucpr:0.61911
# [804]	validation_0-aucpr:0.61908
# [805]	validation_0-aucpr:0.61911
# [806]	validation_0-aucpr:0.61910
# [807]	validation_0-aucpr:0.61908
# [808]	validation_0-aucpr:0.61915
# [809]	validation_0-aucpr:0.61918
# [810]	validation_0-aucpr:0.61920
# [811]	validation_0-aucpr:0.61928
# [812]	validation_0-aucpr:0.61930
# [813]	validation_0-aucpr:0.61935
# [814]	validation_0-aucpr:0.61934
# [815]	validation_0-aucpr:0.61939
# [816]	validation_0-aucpr:0.61935
# [817]	validation_0-aucpr:0.61943
# [818]	validation_0-aucpr:0.61948
# [819]	validation_0-aucpr:0.61954
# [820]	validation_0-aucpr:0.61961
# [821]	validation_0-aucpr:0.61966
# [822]	validation_0-aucpr:0.61976
# [823]	validation_0-aucpr:0.61983
# [824]	validation_0-aucpr:0.61988
# [825]	validation_0-aucpr:0.61988
# [826]	validation_0-aucpr:0.61994
# [827]	validation_0-aucpr:0.61991
# [828]	validation_0-aucpr:0.61983
# [829]	validation_0-aucpr:0.61987
# [830]	validation_0-aucpr:0.61987
# [831]	validation_0-aucpr:0.61991
# [832]	validation_0-aucpr:0.61991
# [833]	validation_0-aucpr:0.61993
# [834]	validation_0-aucpr:0.61999
# [835]	validation_0-aucpr:0.62001
# [836]	validation_0-aucpr:0.61999
# [837]	validation_0-aucpr:0.62007
# [838]	validation_0-aucpr:0.62013
# [839]	validation_0-aucpr:0.62011
# [840]	validation_0-aucpr:0.62010
# [841]	validation_0-aucpr:0.62012
# [842]	validation_0-aucpr:0.62019
# [843]	validation_0-aucpr:0.62025
# [844]	validation_0-aucpr:0.62032
# [845]	validation_0-aucpr:0.62035
# [846]	validation_0-aucpr:0.62035
# [847]	validation_0-aucpr:0.62044
# [848]	validation_0-aucpr:0.62049
# [849]	validation_0-aucpr:0.62053
# [850]	validation_0-aucpr:0.62053
# [851]	validation_0-aucpr:0.62055
# [852]	validation_0-aucpr:0.62055
# [853]	validation_0-aucpr:0.62052
# [854]	validation_0-aucpr:0.62055
# [855]	validation_0-aucpr:0.62062
# [856]	validation_0-aucpr:0.62056
# [857]	validation_0-aucpr:0.62057
# [858]	validation_0-aucpr:0.62059
# [859]	validation_0-aucpr:0.62062
# [860]	validation_0-aucpr:0.62069
# [861]	validation_0-aucpr:0.62069
# [862]	validation_0-aucpr:0.62064
# [863]	validation_0-aucpr:0.62063
# [864]	validation_0-aucpr:0.62062
# [865]	validation_0-aucpr:0.62061
# [866]	validation_0-aucpr:0.62058
# [867]	validation_0-aucpr:0.62061
# [868]	validation_0-aucpr:0.62065
# [869]	validation_0-aucpr:0.62071
# [870]	validation_0-aucpr:0.62066
# [871]	validation_0-aucpr:0.62067
# [872]	validation_0-aucpr:0.62071
# [873]	validation_0-aucpr:0.62072
# [874]	validation_0-aucpr:0.62080
# [875]	validation_0-aucpr:0.62080
# [876]	validation_0-aucpr:0.62076
# [877]	validation_0-aucpr:0.62079
# [878]	validation_0-aucpr:0.62088
# [879]	validation_0-aucpr:0.62095
# [880]	validation_0-aucpr:0.62104
# [881]	validation_0-aucpr:0.62095
# [882]	validation_0-aucpr:0.62097
# [883]	validation_0-aucpr:0.62100
# [884]	validation_0-aucpr:0.62099
# [885]	validation_0-aucpr:0.62099
# [886]	validation_0-aucpr:0.62100
# [887]	validation_0-aucpr:0.62100
# [888]	validation_0-aucpr:0.62103
# [889]	validation_0-aucpr:0.62104
# [890]	validation_0-aucpr:0.62109
# [891]	validation_0-aucpr:0.62112
# [892]	validation_0-aucpr:0.62116
# [893]	validation_0-aucpr:0.62125
# [894]	validation_0-aucpr:0.62125
# [895]	validation_0-aucpr:0.62127
# [896]	validation_0-aucpr:0.62124
# [897]	validation_0-aucpr:0.62120
# [898]	validation_0-aucpr:0.62129
# [899]	validation_0-aucpr:0.62127
# [900]	validation_0-aucpr:0.62133
# [901]	validation_0-aucpr:0.62145
# [902]	validation_0-aucpr:0.62148
# [903]	validation_0-aucpr:0.62153
# [904]	validation_0-aucpr:0.62158
# [905]	validation_0-aucpr:0.62159
# [906]	validation_0-aucpr:0.62157
# [907]	validation_0-aucpr:0.62153
# [908]	validation_0-aucpr:0.62148
# [909]	validation_0-aucpr:0.62155
# [910]	validation_0-aucpr:0.62154
# [911]	validation_0-aucpr:0.62163
# [912]	validation_0-aucpr:0.62168
# [913]	validation_0-aucpr:0.62174
# [914]	validation_0-aucpr:0.62177
# [915]	validation_0-aucpr:0.62183
# [916]	validation_0-aucpr:0.62193
# [917]	validation_0-aucpr:0.62198
# [918]	validation_0-aucpr:0.62199
# [919]	validation_0-aucpr:0.62203
# [920]	validation_0-aucpr:0.62209
# [921]	validation_0-aucpr:0.62213
# [922]	validation_0-aucpr:0.62215
# [923]	validation_0-aucpr:0.62215
# [924]	validation_0-aucpr:0.62219
# [925]	validation_0-aucpr:0.62228
# [926]	validation_0-aucpr:0.62230
# [927]	validation_0-aucpr:0.62230
# [928]	validation_0-aucpr:0.62239
# [929]	validation_0-aucpr:0.62242
# [930]	validation_0-aucpr:0.62248
# [931]	validation_0-aucpr:0.62245
# [932]	validation_0-aucpr:0.62243
# [933]	validation_0-aucpr:0.62247
# [934]	validation_0-aucpr:0.62251
# [935]	validation_0-aucpr:0.62254
# [936]	validation_0-aucpr:0.62263
# [937]	validation_0-aucpr:0.62262
# [938]	validation_0-aucpr:0.62265
# [939]	validation_0-aucpr:0.62269
# [940]	validation_0-aucpr:0.62275
# [941]	validation_0-aucpr:0.62274
# [942]	validation_0-aucpr:0.62276
# [943]	validation_0-aucpr:0.62275
# [944]	validation_0-aucpr:0.62285
# [945]	validation_0-aucpr:0.62292
# [946]	validation_0-aucpr:0.62293
# [947]	validation_0-aucpr:0.62297
# [948]	validation_0-aucpr:0.62292
# [949]	validation_0-aucpr:0.62290
# [950]	validation_0-aucpr:0.62293
# [951]	validation_0-aucpr:0.62291
# [952]	validation_0-aucpr:0.62297
# [953]	validation_0-aucpr:0.62304
# [954]	validation_0-aucpr:0.62303
# [955]	validation_0-aucpr:0.62299
# [956]	validation_0-aucpr:0.62301
# [957]	validation_0-aucpr:0.62299
# [958]	validation_0-aucpr:0.62302
# [959]	validation_0-aucpr:0.62306
# [960]	validation_0-aucpr:0.62302
# [961]	validation_0-aucpr:0.62299
# [962]	validation_0-aucpr:0.62312
# [963]	validation_0-aucpr:0.62312
# [964]	validation_0-aucpr:0.62313
# [965]	validation_0-aucpr:0.62316
# [966]	validation_0-aucpr:0.62311
# [967]	validation_0-aucpr:0.62308
# [968]	validation_0-aucpr:0.62307
# [969]	validation_0-aucpr:0.62308
# [970]	validation_0-aucpr:0.62300
# [971]	validation_0-aucpr:0.62308
# [972]	validation_0-aucpr:0.62309
# [973]	validation_0-aucpr:0.62312
# [974]	validation_0-aucpr:0.62309
# [975]	validation_0-aucpr:0.62315
# [976]	validation_0-aucpr:0.62320
# [977]	validation_0-aucpr:0.62325
# [978]	validation_0-aucpr:0.62322
# [979]	validation_0-aucpr:0.62325
# [980]	validation_0-aucpr:0.62322
# [981]	validation_0-aucpr:0.62329
# [982]	validation_0-aucpr:0.62329
# [983]	validation_0-aucpr:0.62330
# [984]	validation_0-aucpr:0.62322
# [985]	validation_0-aucpr:0.62329
# [986]	validation_0-aucpr:0.62326
# [987]	validation_0-aucpr:0.62329
# [988]	validation_0-aucpr:0.62329
# [989]	validation_0-aucpr:0.62329
# [990]	validation_0-aucpr:0.62329
# [991]	validation_0-aucpr:0.62335
# [992]	validation_0-aucpr:0.62338
# [993]	validation_0-aucpr:0.62347
# [994]	validation_0-aucpr:0.62349
# [995]	validation_0-aucpr:0.62349
# [996]	validation_0-aucpr:0.62352
# [997]	validation_0-aucpr:0.62346
# [998]	validation_0-aucpr:0.62347
# [999]	validation_0-aucpr:0.62356
# [1000]	validation_0-aucpr:0.62353
# [1001]	validation_0-aucpr:0.62359
# [1002]	validation_0-aucpr:0.62362
# [1003]	validation_0-aucpr:0.62365
# [1004]	validation_0-aucpr:0.62362
# [1005]	validation_0-aucpr:0.62364
# [1006]	validation_0-aucpr:0.62374
# [1007]	validation_0-aucpr:0.62373
# [1008]	validation_0-aucpr:0.62368
# [1009]	validation_0-aucpr:0.62377
# [1010]	validation_0-aucpr:0.62383
# [1011]	validation_0-aucpr:0.62390
# [1012]	validation_0-aucpr:0.62390
# [1013]	validation_0-aucpr:0.62391
# [1014]	validation_0-aucpr:0.62401
# [1015]	validation_0-aucpr:0.62400
# [1016]	validation_0-aucpr:0.62403
# [1017]	validation_0-aucpr:0.62402
# [1018]	validation_0-aucpr:0.62401
# [1019]	validation_0-aucpr:0.62400
# [1020]	validation_0-aucpr:0.62403
# [1021]	validation_0-aucpr:0.62409
# [1022]	validation_0-aucpr:0.62418
# [1023]	validation_0-aucpr:0.62417
# [1024]	validation_0-aucpr:0.62421
# [1025]	validation_0-aucpr:0.62424
# [1026]	validation_0-aucpr:0.62428
# [1027]	validation_0-aucpr:0.62428
# [1028]	validation_0-aucpr:0.62423
# [1029]	validation_0-aucpr:0.62424
# [1030]	validation_0-aucpr:0.62423
# [1031]	validation_0-aucpr:0.62423
# [1032]	validation_0-aucpr:0.62419
# [1033]	validation_0-aucpr:0.62420
# [1034]	validation_0-aucpr:0.62418
# [1035]	validation_0-aucpr:0.62424
# [1036]	validation_0-aucpr:0.62422
# [1037]	validation_0-aucpr:0.62429
# [1038]	validation_0-aucpr:0.62419
# [1039]	validation_0-aucpr:0.62420
# [1040]	validation_0-aucpr:0.62425
# [1041]	validation_0-aucpr:0.62422
# [1042]	validation_0-aucpr:0.62421
# [1043]	validation_0-aucpr:0.62426
# [1044]	validation_0-aucpr:0.62425
# [1045]	validation_0-aucpr:0.62423
# [1046]	validation_0-aucpr:0.62427
# [1047]	validation_0-aucpr:0.62430
# [1048]	validation_0-aucpr:0.62446
# [1049]	validation_0-aucpr:0.62448
# [1050]	validation_0-aucpr:0.62447
# [1051]	validation_0-aucpr:0.62452
# [1052]	validation_0-aucpr:0.62461
# [1053]	validation_0-aucpr:0.62454
# [1054]	validation_0-aucpr:0.62449
# [1055]	validation_0-aucpr:0.62450
# [1056]	validation_0-aucpr:0.62448
# [1057]	validation_0-aucpr:0.62446
# [1058]	validation_0-aucpr:0.62452
# [1059]	validation_0-aucpr:0.62452
# [1060]	validation_0-aucpr:0.62458
# [1061]	validation_0-aucpr:0.62455
# [1062]	validation_0-aucpr:0.62453
# [1063]	validation_0-aucpr:0.62452
# [1064]	validation_0-aucpr:0.62453
# [1065]	validation_0-aucpr:0.62454
# [1066]	validation_0-aucpr:0.62456
# [1067]	validation_0-aucpr:0.62462
# [1068]	validation_0-aucpr:0.62463
# [1069]	validation_0-aucpr:0.62467
# [1070]	validation_0-aucpr:0.62462
# [1071]	validation_0-aucpr:0.62462
# [1072]	validation_0-aucpr:0.62467
# [1073]	validation_0-aucpr:0.62470
# [1074]	validation_0-aucpr:0.62468
# [1075]	validation_0-aucpr:0.62458
# [1076]	validation_0-aucpr:0.62464
# [1077]	validation_0-aucpr:0.62461
# [1078]	validation_0-aucpr:0.62459
# [1079]	validation_0-aucpr:0.62466
# [1080]	validation_0-aucpr:0.62467
# [1081]	validation_0-aucpr:0.62473
# [1082]	validation_0-aucpr:0.62473
# [1083]	validation_0-aucpr:0.62474
# [1084]	validation_0-aucpr:0.62473
# [1085]	validation_0-aucpr:0.62473
# [1086]	validation_0-aucpr:0.62466
# [1087]	validation_0-aucpr:0.62468
# [1088]	validation_0-aucpr:0.62469
# [1089]	validation_0-aucpr:0.62468
# [1090]	validation_0-aucpr:0.62473
# [1091]	validation_0-aucpr:0.62475
# [1092]	validation_0-aucpr:0.62476
# [1093]	validation_0-aucpr:0.62478
# [1094]	validation_0-aucpr:0.62478
# [1095]	validation_0-aucpr:0.62481
# [1096]	validation_0-aucpr:0.62480
# [1097]	validation_0-aucpr:0.62481
# [1098]	validation_0-aucpr:0.62481
# [1099]	validation_0-aucpr:0.62486
# [1100]	validation_0-aucpr:0.62484
# [1101]	validation_0-aucpr:0.62489
# [1102]	validation_0-aucpr:0.62489
# [1103]	validation_0-aucpr:0.62495
# [1104]	validation_0-aucpr:0.62494
# [1105]	validation_0-aucpr:0.62496
# [1106]	validation_0-aucpr:0.62494
# [1107]	validation_0-aucpr:0.62495
# [1108]	validation_0-aucpr:0.62498
# [1109]	validation_0-aucpr:0.62503
# [1110]	validation_0-aucpr:0.62507
# [1111]	validation_0-aucpr:0.62511
# [1112]	validation_0-aucpr:0.62517
# [1113]	validation_0-aucpr:0.62519
# [1114]	validation_0-aucpr:0.62524
# [1115]	validation_0-aucpr:0.62521
# [1116]	validation_0-aucpr:0.62521
# [1117]	validation_0-aucpr:0.62520
# [1118]	validation_0-aucpr:0.62522
# [1119]	validation_0-aucpr:0.62521
# [1120]	validation_0-aucpr:0.62527
# [1121]	validation_0-aucpr:0.62530
# [1122]	validation_0-aucpr:0.62541
# [1123]	validation_0-aucpr:0.62534
# [1124]	validation_0-aucpr:0.62534
# [1125]	validation_0-aucpr:0.62531
# [1126]	validation_0-aucpr:0.62533
# [1127]	validation_0-aucpr:0.62537
# [1128]	validation_0-aucpr:0.62529
# [1129]	validation_0-aucpr:0.62533
# [1130]	validation_0-aucpr:0.62529
# [1131]	validation_0-aucpr:0.62532
# [1132]	validation_0-aucpr:0.62532
# [1133]	validation_0-aucpr:0.62536
# [1134]	validation_0-aucpr:0.62538
# [1135]	validation_0-aucpr:0.62535
# [1136]	validation_0-aucpr:0.62536
# [1137]	validation_0-aucpr:0.62539
# [1138]	validation_0-aucpr:0.62538
# [1139]	validation_0-aucpr:0.62541
# [1140]	validation_0-aucpr:0.62552
# [1141]	validation_0-aucpr:0.62560
# [1142]	validation_0-aucpr:0.62562
# [1143]	validation_0-aucpr:0.62568
# [1144]	validation_0-aucpr:0.62572
# [1145]	validation_0-aucpr:0.62577
# [1146]	validation_0-aucpr:0.62579
# [1147]	validation_0-aucpr:0.62577
# [1148]	validation_0-aucpr:0.62572
# [1149]	validation_0-aucpr:0.62572
# [1150]	validation_0-aucpr:0.62579
# [1151]	validation_0-aucpr:0.62581
# [1152]	validation_0-aucpr:0.62580
# [1153]	validation_0-aucpr:0.62578
# [1154]	validation_0-aucpr:0.62584
# [1155]	validation_0-aucpr:0.62583
# [1156]	validation_0-aucpr:0.62581
# [1157]	validation_0-aucpr:0.62580
# [1158]	validation_0-aucpr:0.62581
# [1159]	validation_0-aucpr:0.62584
# [1160]	validation_0-aucpr:0.62584
# [1161]	validation_0-aucpr:0.62583
# [1162]	validation_0-aucpr:0.62584
# [1163]	validation_0-aucpr:0.62584
# [1164]	validation_0-aucpr:0.62594
# [1165]	validation_0-aucpr:0.62596
# [1166]	validation_0-aucpr:0.62595
# [1167]	validation_0-aucpr:0.62595
# [1168]	validation_0-aucpr:0.62597
# [1169]	validation_0-aucpr:0.62598
# [1170]	validation_0-aucpr:0.62602
# [1171]	validation_0-aucpr:0.62605
# [1172]	validation_0-aucpr:0.62605
# [1173]	validation_0-aucpr:0.62608
# [1174]	validation_0-aucpr:0.62608
# [1175]	validation_0-aucpr:0.62607
# ...
# [3878]	validation_0-aucpr:0.81981
# [3879]	validation_0-aucpr:0.81982
# [3880]	validation_0-aucpr:0.81985
# [3881]	validation_0-aucpr:0.81985
# [3882]	validation_0-aucpr:0.81986
# [3883]	validation_0-aucpr:0.81987
# [3884]	validation_0-aucpr:0.81987
# [3885]	validation_0-aucpr:0.81986
# [3886]	validation_0-aucpr:0.81986
# [3887]	validation_0-aucpr:0.81987
# [3888]	validation_0-aucpr:0.81987
# [3889]	validation_0-aucpr:0.81988
# [3890]	validation_0-aucpr:0.81987
# [3891]	validation_0-aucpr:0.81987
# [3892]	validation_0-aucpr:0.81987
# [3893]	validation_0-aucpr:0.81989
# [3894]	validation_0-aucpr:0.81990
# [3895]	validation_0-aucpr:0.81991
# [3896]	validation_0-aucpr:0.81991
# [3897]	validation_0-aucpr:0.81991
# [3898]	validation_0-aucpr:0.81990
# [3899]	validation_0-aucpr:0.81990
# [3900]	validation_0-aucpr:0.81990
# [3901]	validation_0-aucpr:0.81989
# [3902]	validation_0-aucpr:0.81988
# [3903]	validation_0-aucpr:0.81989
# [3904]	validation_0-aucpr:0.81990
# [3905]	validation_0-aucpr:0.81990
# [3906]	validation_0-aucpr:0.81989
# [3907]	validation_0-aucpr:0.81989
# [3908]	validation_0-aucpr:0.81991
# [3909]	validation_0-aucpr:0.81991
# [3910]	validation_0-aucpr:0.81993
# [3911]	validation_0-aucpr:0.81994
# [3912]	validation_0-aucpr:0.81994
# [3913]	validation_0-aucpr:0.81994
# [3914]	validation_0-aucpr:0.81996
# [3915]	validation_0-aucpr:0.81996
# [3916]	validation_0-aucpr:0.81998
# [3917]	validation_0-aucpr:0.81999
# [3918]	validation_0-aucpr:0.82000
# [3919]	validation_0-aucpr:0.82001
# [3920]	validation_0-aucpr:0.82001
# [3921]	validation_0-aucpr:0.82002
# [3922]	validation_0-aucpr:0.82001
# [3923]	validation_0-aucpr:0.82002
# [3924]	validation_0-aucpr:0.82003
# [3925]	validation_0-aucpr:0.82003
# [3926]	validation_0-aucpr:0.82004
# [3927]	validation_0-aucpr:0.82006
# [3928]	validation_0-aucpr:0.82006
# [3929]	validation_0-aucpr:0.82005
# [3930]	validation_0-aucpr:0.82006
# [3931]	validation_0-aucpr:0.82006
# [3932]	validation_0-aucpr:0.82006
# [3933]	validation_0-aucpr:0.82006
# [3934]	validation_0-aucpr:0.82008
# [3935]	validation_0-aucpr:0.82008
# [3936]	validation_0-aucpr:0.82007
# [3937]	validation_0-aucpr:0.82008
# [3938]	validation_0-aucpr:0.82008
# [3939]	validation_0-aucpr:0.82010
# [3940]	validation_0-aucpr:0.82011
# [3941]	validation_0-aucpr:0.82010
# [3942]	validation_0-aucpr:0.82010
# [3943]	validation_0-aucpr:0.82009
# [3944]	validation_0-aucpr:0.82010
# [3945]	validation_0-aucpr:0.82010
# [3946]	validation_0-aucpr:0.82011
# [3947]	validation_0-aucpr:0.82012
# [3948]	validation_0-aucpr:0.82013
# [3949]	validation_0-aucpr:0.82014
# [3950]	validation_0-aucpr:0.82015
# [3951]	validation_0-aucpr:0.82017
# [3952]	validation_0-aucpr:0.82019
# [3953]	validation_0-aucpr:0.82018
# [3954]	validation_0-aucpr:0.82017
# [3955]	validation_0-aucpr:0.82017
# [3956]	validation_0-aucpr:0.82019
# [3957]	validation_0-aucpr:0.82018
# [3958]	validation_0-aucpr:0.82017
# [3959]	validation_0-aucpr:0.82017
# [3960]	validation_0-aucpr:0.82019
# [3961]	validation_0-aucpr:0.82018
# [3962]	validation_0-aucpr:0.82020
# [3963]	validation_0-aucpr:0.82019
# [3964]	validation_0-aucpr:0.82017
# [3965]	validation_0-aucpr:0.82017
# [3966]	validation_0-aucpr:0.82016
# [3967]	validation_0-aucpr:0.82016
# [3968]	validation_0-aucpr:0.82017
# [3969]	validation_0-aucpr:0.82017
# [3970]	validation_0-aucpr:0.82016
# [3971]	validation_0-aucpr:0.82014
# [3972]	validation_0-aucpr:0.82014
# [3973]	validation_0-aucpr:0.82014
# [3974]	validation_0-aucpr:0.82014
# [3975]	validation_0-aucpr:0.82015
# [3976]	validation_0-aucpr:0.82015
# [3977]	validation_0-aucpr:0.82014
# [3978]	validation_0-aucpr:0.82017
# [3979]	validation_0-aucpr:0.82017
# [3980]	validation_0-aucpr:0.82016
# [3981]	validation_0-aucpr:0.82017
# [3982]	validation_0-aucpr:0.82016
# [3983]	validation_0-aucpr:0.82016
# [3984]	validation_0-aucpr:0.82017
# [3985]	validation_0-aucpr:0.82016
# [3986]	validation_0-aucpr:0.82017
# [3987]	validation_0-aucpr:0.82017
# [3988]	validation_0-aucpr:0.82019
# [3989]	validation_0-aucpr:0.82020
# [3990]	validation_0-aucpr:0.82021
# [3991]	validation_0-aucpr:0.82023
# [3992]	validation_0-aucpr:0.82023
# [3993]	validation_0-aucpr:0.82023
# [3994]	validation_0-aucpr:0.82024
# [3995]	validation_0-aucpr:0.82025
# [3996]	validation_0-aucpr:0.82025
# [3997]	validation_0-aucpr:0.82026
# [3998]	validation_0-aucpr:0.82026
# [3999]	validation_0-aucpr:0.82028
# [4000]	validation_0-aucpr:0.82029
# [4001]	validation_0-aucpr:0.82030
# [4002]	validation_0-aucpr:0.82029
# [4003]	validation_0-aucpr:0.82028
# [4004]	validation_0-aucpr:0.82029
# [4005]	validation_0-aucpr:0.82028
# [4006]	validation_0-aucpr:0.82028
# [4007]	validation_0-aucpr:0.82028
# [4008]	validation_0-aucpr:0.82027
# [4009]	validation_0-aucpr:0.82027
# [4010]	validation_0-aucpr:0.82027
# [4011]	validation_0-aucpr:0.82026
# [4012]	validation_0-aucpr:0.82028
# [4013]	validation_0-aucpr:0.82029
# [4014]	validation_0-aucpr:0.82029
# [4015]	validation_0-aucpr:0.82030
# [4016]	validation_0-aucpr:0.82031
# [4017]	validation_0-aucpr:0.82030
# [4018]	validation_0-aucpr:0.82031
# [4019]	validation_0-aucpr:0.82030
# [4020]	validation_0-aucpr:0.82030
# [4021]	validation_0-aucpr:0.82029
# [4022]	validation_0-aucpr:0.82029
# [4023]	validation_0-aucpr:0.82030
# [4024]	validation_0-aucpr:0.82030
# [4025]	validation_0-aucpr:0.82032
# [4026]	validation_0-aucpr:0.82033
# [4027]	validation_0-aucpr:0.82033
# [4028]	validation_0-aucpr:0.82033
# [4029]	validation_0-aucpr:0.82032
# [4030]	validation_0-aucpr:0.82033
# [4031]	validation_0-aucpr:0.82033
# [4032]	validation_0-aucpr:0.82033
# [4033]	validation_0-aucpr:0.82032
# [4034]	validation_0-aucpr:0.82031
# [4035]	validation_0-aucpr:0.82031
# [4036]	validation_0-aucpr:0.82032
# [4037]	validation_0-aucpr:0.82033
# [4038]	validation_0-aucpr:0.82032
# [4039]	validation_0-aucpr:0.82032
# [4040]	validation_0-aucpr:0.82031
# [4041]	validation_0-aucpr:0.82033
# [4042]	validation_0-aucpr:0.82033
# [4043]	validation_0-aucpr:0.82032
# [4044]	validation_0-aucpr:0.82032
# [4045]	validation_0-aucpr:0.82034
# [4046]	validation_0-aucpr:0.82034
# [4047]	validation_0-aucpr:0.82035
# [4048]	validation_0-aucpr:0.82036
# [4049]	validation_0-aucpr:0.82035
# [4050]	validation_0-aucpr:0.82037
# [4051]	validation_0-aucpr:0.82040
# [4052]	validation_0-aucpr:0.82040
# [4053]	validation_0-aucpr:0.82041
# [4054]	validation_0-aucpr:0.82042
# [4055]	validation_0-aucpr:0.82041
# [4056]	validation_0-aucpr:0.82043
# [4057]	validation_0-aucpr:0.82042
# [4058]	validation_0-aucpr:0.82042
# [4059]	validation_0-aucpr:0.82043
# [4060]	validation_0-aucpr:0.82044
# [4061]	validation_0-aucpr:0.82044
# [4062]	validation_0-aucpr:0.82044
# [4063]	validation_0-aucpr:0.82045
# [4064]	validation_0-aucpr:0.82044
# [4065]	validation_0-aucpr:0.82043
# [4066]	validation_0-aucpr:0.82043
# [4067]	validation_0-aucpr:0.82043
# [4068]	validation_0-aucpr:0.82043
# [4069]	validation_0-aucpr:0.82044
# [4070]	validation_0-aucpr:0.82044
# [4071]	validation_0-aucpr:0.82046
# [4072]	validation_0-aucpr:0.82046
# [4073]	validation_0-aucpr:0.82046
# [4074]	validation_0-aucpr:0.82045
# [4075]	validation_0-aucpr:0.82045
# [4076]	validation_0-aucpr:0.82045
# [4077]	validation_0-aucpr:0.82044
# [4078]	validation_0-aucpr:0.82044
# [4079]	validation_0-aucpr:0.82046
# [4080]	validation_0-aucpr:0.82046
# [4081]	validation_0-aucpr:0.82046
# [4082]	validation_0-aucpr:0.82046
# [4083]	validation_0-aucpr:0.82046
# [4084]	validation_0-aucpr:0.82046
# [4085]	validation_0-aucpr:0.82048
# [4086]	validation_0-aucpr:0.82048
# [4087]	validation_0-aucpr:0.82047
# [4088]	validation_0-aucpr:0.82047
# [4089]	validation_0-aucpr:0.82047
# [4090]	validation_0-aucpr:0.82048
# [4091]	validation_0-aucpr:0.82047
# [4092]	validation_0-aucpr:0.82047
# [4093]	validation_0-aucpr:0.82047
# [4094]	validation_0-aucpr:0.82048
# [4095]	validation_0-aucpr:0.82049
# [4096]	validation_0-aucpr:0.82048
# [4097]	validation_0-aucpr:0.82049
# [4098]	validation_0-aucpr:0.82049
# [4099]	validation_0-aucpr:0.82051
# [4100]	validation_0-aucpr:0.82051
# [4101]	validation_0-aucpr:0.82052
# [4102]	validation_0-aucpr:0.82052
# [4103]	validation_0-aucpr:0.82052
# [4104]	validation_0-aucpr:0.82054
# [4105]	validation_0-aucpr:0.82054
# [4106]	validation_0-aucpr:0.82055
# [4107]	validation_0-aucpr:0.82055
# [4108]	validation_0-aucpr:0.82056
# [4109]	validation_0-aucpr:0.82057
# [4110]	validation_0-aucpr:0.82058
# [4111]	validation_0-aucpr:0.82058
# [4112]	validation_0-aucpr:0.82059
# [4113]	validation_0-aucpr:0.82060
# [4114]	validation_0-aucpr:0.82062
# [4115]	validation_0-aucpr:0.82062
# [4116]	validation_0-aucpr:0.82064
# [4117]	validation_0-aucpr:0.82064
# [4118]	validation_0-aucpr:0.82063
# [4119]	validation_0-aucpr:0.82064
# [4120]	validation_0-aucpr:0.82064
# [4121]	validation_0-aucpr:0.82065
# [4122]	validation_0-aucpr:0.82064
# [4123]	validation_0-aucpr:0.82066
# [4124]	validation_0-aucpr:0.82065
# [4125]	validation_0-aucpr:0.82065
# [4126]	validation_0-aucpr:0.82066
# [4127]	validation_0-aucpr:0.82068
# [4128]	validation_0-aucpr:0.82070
# [4129]	validation_0-aucpr:0.82072
# [4130]	validation_0-aucpr:0.82072
# [4131]	validation_0-aucpr:0.82072
# [4132]	validation_0-aucpr:0.82072
# [4133]	validation_0-aucpr:0.82073
# [4134]	validation_0-aucpr:0.82071
# [4135]	validation_0-aucpr:0.82072
# [4136]	validation_0-aucpr:0.82071
# [4137]	validation_0-aucpr:0.82071
# [4138]	validation_0-aucpr:0.82071
# [4139]	validation_0-aucpr:0.82071
# [4140]	validation_0-aucpr:0.82071
# [4141]	validation_0-aucpr:0.82072
# [4142]	validation_0-aucpr:0.82072
# [4143]	validation_0-aucpr:0.82074
# [4144]	validation_0-aucpr:0.82075
# [4145]	validation_0-aucpr:0.82074
# [4146]	validation_0-aucpr:0.82074
# [4147]	validation_0-aucpr:0.82074
# [4148]	validation_0-aucpr:0.82074
# [4149]	validation_0-aucpr:0.82074
# [4150]	validation_0-aucpr:0.82075
# [4151]	validation_0-aucpr:0.82075
# [4152]	validation_0-aucpr:0.82076
# [4153]	validation_0-aucpr:0.82077
# [4154]	validation_0-aucpr:0.82078
# [4155]	validation_0-aucpr:0.82079
# [4156]	validation_0-aucpr:0.82079
# [4157]	validation_0-aucpr:0.82079
# [4158]	validation_0-aucpr:0.82079
# [4159]	validation_0-aucpr:0.82081
# [4160]	validation_0-aucpr:0.82081
# [4161]	validation_0-aucpr:0.82081
# [4162]	validation_0-aucpr:0.82079
# [4163]	validation_0-aucpr:0.82081
# [4164]	validation_0-aucpr:0.82082
# [4165]	validation_0-aucpr:0.82083
# [4166]	validation_0-aucpr:0.82084
# [4167]	validation_0-aucpr:0.82083
# [4168]	validation_0-aucpr:0.82084
# [4169]	validation_0-aucpr:0.82085
# [4170]	validation_0-aucpr:0.82084
# [4171]	validation_0-aucpr:0.82081
# [4172]	validation_0-aucpr:0.82081
# [4173]	validation_0-aucpr:0.82081
# [4174]	validation_0-aucpr:0.82079
# [4175]	validation_0-aucpr:0.82082
# [4176]	validation_0-aucpr:0.82082
# [4177]	validation_0-aucpr:0.82083
# [4178]	validation_0-aucpr:0.82082
# [4179]	validation_0-aucpr:0.82082
# [4180]	validation_0-aucpr:0.82082
# [4181]	validation_0-aucpr:0.82083
# [4182]	validation_0-aucpr:0.82084
# [4183]	validation_0-aucpr:0.82084
# [4184]	validation_0-aucpr:0.82084
# [4185]	validation_0-aucpr:0.82084
# [4186]	validation_0-aucpr:0.82085
# [4187]	validation_0-aucpr:0.82085
# [4188]	validation_0-aucpr:0.82086
# [4189]	validation_0-aucpr:0.82088
# [4190]	validation_0-aucpr:0.82088
# [4191]	validation_0-aucpr:0.82087
# [4192]	validation_0-aucpr:0.82088
# [4193]	validation_0-aucpr:0.82089
# [4194]	validation_0-aucpr:0.82088
# [4195]	validation_0-aucpr:0.82089
# [4196]	validation_0-aucpr:0.82089
# [4197]	validation_0-aucpr:0.82088
# [4198]	validation_0-aucpr:0.82089
# [4199]	validation_0-aucpr:0.82088
# [4200]	validation_0-aucpr:0.82089
# [4201]	validation_0-aucpr:0.82089
# [4202]	validation_0-aucpr:0.82089
# [4203]	validation_0-aucpr:0.82088
# [4204]	validation_0-aucpr:0.82089
# [4205]	validation_0-aucpr:0.82089
# [4206]	validation_0-aucpr:0.82089
# [4207]	validation_0-aucpr:0.82089
# [4208]	validation_0-aucpr:0.82090
# [4209]	validation_0-aucpr:0.82088
# [4210]	validation_0-aucpr:0.82088
# [4211]	validation_0-aucpr:0.82090
# [4212]	validation_0-aucpr:0.82090
# [4213]	validation_0-aucpr:0.82089
# [4214]	validation_0-aucpr:0.82088
# [4215]	validation_0-aucpr:0.82087
# [4216]	validation_0-aucpr:0.82087
# [4217]	validation_0-aucpr:0.82087
# [4218]	validation_0-aucpr:0.82087
# [4219]	validation_0-aucpr:0.82087
# [4220]	validation_0-aucpr:0.82088
# [4221]	validation_0-aucpr:0.82088
# [4222]	validation_0-aucpr:0.82089
# [4223]	validation_0-aucpr:0.82089
# [4224]	validation_0-aucpr:0.82090
# [4225]	validation_0-aucpr:0.82090
# [4226]	validation_0-aucpr:0.82089
# [4227]	validation_0-aucpr:0.82089
# [4228]	validation_0-aucpr:0.82090
# [4229]	validation_0-aucpr:0.82090
# [4230]	validation_0-aucpr:0.82090
# [4231]	validation_0-aucpr:0.82089
# [4232]	validation_0-aucpr:0.82090
# [4233]	validation_0-aucpr:0.82090
# [4234]	validation_0-aucpr:0.82091
# [4235]	validation_0-aucpr:0.82092
# [4236]	validation_0-aucpr:0.82092
# [4237]	validation_0-aucpr:0.82091
# [4238]	validation_0-aucpr:0.82090
# [4239]	validation_0-aucpr:0.82092
# [4240]	validation_0-aucpr:0.82091
# [4241]	validation_0-aucpr:0.82090
# [4242]	validation_0-aucpr:0.82092
# [4243]	validation_0-aucpr:0.82094
# [4244]	validation_0-aucpr:0.82094
# [4245]	validation_0-aucpr:0.82094
# [4246]	validation_0-aucpr:0.82094
# [4247]	validation_0-aucpr:0.82095
# [4248]	validation_0-aucpr:0.82095
# [4249]	validation_0-aucpr:0.82094
# [4250]	validation_0-aucpr:0.82094
# [4251]	validation_0-aucpr:0.82095
# [4252]	validation_0-aucpr:0.82096
# [4253]	validation_0-aucpr:0.82094
# [4254]	validation_0-aucpr:0.82095
# [4255]	validation_0-aucpr:0.82094
# [4256]	validation_0-aucpr:0.82095
# [4257]	validation_0-aucpr:0.82096
# [4258]	validation_0-aucpr:0.82097
# [4259]	validation_0-aucpr:0.82097
# [4260]	validation_0-aucpr:0.82097
# [4261]	validation_0-aucpr:0.82097
# [4262]	validation_0-aucpr:0.82098
# [4263]	validation_0-aucpr:0.82098
# [4264]	validation_0-aucpr:0.82098
# [4265]	validation_0-aucpr:0.82097
# [4266]	validation_0-aucpr:0.82098
# [4267]	validation_0-aucpr:0.82099
# [4268]	validation_0-aucpr:0.82099
# [4269]	validation_0-aucpr:0.82099
# [4270]	validation_0-aucpr:0.82100
# [4271]	validation_0-aucpr:0.82100
# [4272]	validation_0-aucpr:0.82099
# [4273]	validation_0-aucpr:0.82099
# [4274]	validation_0-aucpr:0.82099
# [4275]	validation_0-aucpr:0.82101
# [4276]	validation_0-aucpr:0.82101
# [4277]	validation_0-aucpr:0.82101
# [4278]	validation_0-aucpr:0.82102
# [4279]	validation_0-aucpr:0.82103
# [4280]	validation_0-aucpr:0.82102
# [4281]	validation_0-aucpr:0.82102
# [4282]	validation_0-aucpr:0.82102
# [4283]	validation_0-aucpr:0.82102
# [4284]	validation_0-aucpr:0.82101
# [4285]	validation_0-aucpr:0.82102
# [4286]	validation_0-aucpr:0.82101
# [4287]	validation_0-aucpr:0.82101
# [4288]	validation_0-aucpr:0.82102
# [4289]	validation_0-aucpr:0.82104
# [4290]	validation_0-aucpr:0.82106
# [4291]	validation_0-aucpr:0.82106
# [4292]	validation_0-aucpr:0.82106
# [4293]	validation_0-aucpr:0.82104
# [4294]	validation_0-aucpr:0.82106
# [4295]	validation_0-aucpr:0.82105
# [4296]	validation_0-aucpr:0.82105
# [4297]	validation_0-aucpr:0.82107
# [4298]	validation_0-aucpr:0.82107
# [4299]	validation_0-aucpr:0.82105
# [4300]	validation_0-aucpr:0.82105
# [4301]	validation_0-aucpr:0.82105
# [4302]	validation_0-aucpr:0.82105
# [4303]	validation_0-aucpr:0.82104
# [4304]	validation_0-aucpr:0.82105
# [4305]	validation_0-aucpr:0.82106
# [4306]	validation_0-aucpr:0.82106
# [4307]	validation_0-aucpr:0.82106
# [4308]	validation_0-aucpr:0.82106
# [4309]	validation_0-aucpr:0.82109
# [4310]	validation_0-aucpr:0.82109
# [4311]	validation_0-aucpr:0.82110
# [4312]	validation_0-aucpr:0.82109
# [4313]	validation_0-aucpr:0.82111
# [4314]	validation_0-aucpr:0.82110
# [4315]	validation_0-aucpr:0.82110
# [4316]	validation_0-aucpr:0.82112
# [4317]	validation_0-aucpr:0.82110
# [4318]	validation_0-aucpr:0.82111
# [4319]	validation_0-aucpr:0.82111
# [4320]	validation_0-aucpr:0.82110
# [4321]	validation_0-aucpr:0.82110
# [4322]	validation_0-aucpr:0.82111
# [4323]	validation_0-aucpr:0.82111
# [4324]	validation_0-aucpr:0.82110
# [4325]	validation_0-aucpr:0.82111
# [4326]	validation_0-aucpr:0.82110
# [4327]	validation_0-aucpr:0.82112
# [4328]	validation_0-aucpr:0.82113
# [4329]	validation_0-aucpr:0.82114
# [4330]	validation_0-aucpr:0.82112
# [4331]	validation_0-aucpr:0.82112
# [4332]	validation_0-aucpr:0.82111
# [4333]	validation_0-aucpr:0.82112
# [4334]	validation_0-aucpr:0.82113
# [4335]	validation_0-aucpr:0.82113
# [4336]	validation_0-aucpr:0.82114
# [4337]	validation_0-aucpr:0.82115
# [4338]	validation_0-aucpr:0.82116
# [4339]	validation_0-aucpr:0.82118
# [4340]	validation_0-aucpr:0.82118
# [4341]	validation_0-aucpr:0.82118
# [4342]	validation_0-aucpr:0.82119
# [4343]	validation_0-aucpr:0.82120
# [4344]	validation_0-aucpr:0.82120
# [4345]	validation_0-aucpr:0.82120
# [4346]	validation_0-aucpr:0.82123
# [4347]	validation_0-aucpr:0.82123

# %%
# 2B: Unified Model
print('\n📊 B) Training Unified XGBoost Model...')

scale_pos_weight_all = calculate_class_weight(y_train_full.values)
unified_model = get_model('XGBoost', is_imbalanced=True, 
                         scale_pos_weight=scale_pos_weight_all)
unified_model.fit(X_train_full, y_train_full, eval_set=[(X_test_full, y_test_full)])

y_pred_unified = unified_model.predict(X_test_full)
y_prob_unified = unified_model.predict_proba(X_test_full)[:, 1]

# Calculate per-segment metrics for unified model
unified_segment_metrics = {}
for segment in SEGMENTS:
    mask = segments_test_full == segment
    y_true_seg = y_test_full[mask]
    y_pred_seg = y_pred_unified[mask]
    y_prob_seg = y_prob_unified[mask]
    
    unified_segment_metrics[segment] = {
        'recall': recall_score(y_true_seg, y_pred_seg, zero_division=0),
        'precision': precision_score(y_true_seg, y_pred_seg, zero_division=0),
        'f1': f1_score(y_true_seg, y_pred_seg, zero_division=0),
        'roc_auc': roc_auc_score(y_true_seg, y_prob_seg) if len(np.unique(y_true_seg)) > 1 else 0,
        'support': len(y_true_seg)
    }

unified_weighted_recall = print_segment_results(
    unified_segment_metrics, SEGMENT_WEIGHTS, '📊 Unified XGBoost Results:'
)

# %%
# Compare Per-Segment vs Unified
print('\n' + '='*70)
print('📊 COMPARISON: Per-Segment vs Unified')
print('='*70)

print(f'''
   Per-Segment Weighted Recall: {per_segment_weighted_recall:.4f}
   Unified Weighted Recall:     {unified_weighted_recall:.4f}
   
   Winner: {'✅ Per-Segment' if per_segment_weighted_recall > unified_weighted_recall else '✅ Unified'}
   Difference: {abs(per_segment_weighted_recall - unified_weighted_recall):.4f}
''')

# Detailed comparison per segment
print('Per-Segment Comparison:')
print('-' * 60)
print(f'{"Segment":20s} {"Per-Seg":>10s} {"Unified":>10s} {"Winner":>15s}')
print('-' * 60)
for segment in SEGMENTS:
    ps_recall = per_segment_result['segment_metrics'][segment]['recall']
    u_recall = unified_segment_metrics[segment]['recall']
    winner = 'Per-Segment' if ps_recall > u_recall else 'Unified' if u_recall > ps_recall else 'Tie'
    print(f'{segment:20s} {ps_recall:>10.4f} {u_recall:>10.4f} {winner:>15s}')

# %% [markdown]
# ## 4️⃣ Experiment 3: Model Comparison (Per-Segment)
#
# **برای هر سگمنت جداگانه:** XGBoost vs LightGBM vs RandomForest vs LogisticRegression

# %%
print('='*80)
print('🔬 EXPERIMENT 3: Model Comparison (Per-Segment)')
print('='*80)

# Train all models for all segments
all_model_results = {}

for model_name in MODELS_TO_TEST:
    print(f'\n📊 Training {model_name} for each segment...')
    
    result = train_per_segment_models(
        model_name=model_name,
        segments=SEGMENTS,
        X_train=X_train_full,
        y_train=y_train_full,
        segments_train=segments_train_full,
        X_test=X_test_full,
        y_test=y_test_full,
        segments_test=segments_test_full,
        imbalanced_segments=IMBALANCED_SEGMENTS
    )
    
    weighted_recall = calculate_weighted_recall(result['segment_metrics'], SEGMENT_WEIGHTS)
    all_model_results[model_name] = result
    
    print(f'   Weighted Recall: {weighted_recall:.4f}')

# %%
# Create comprehensive comparison table
print('\n' + '='*80)
print('📊 Per-Segment Recall Comparison (All Models)')
print('='*80)

# Build comparison dataframe
comparison_data = {'Segment': SEGMENTS}
for model_name in MODELS_TO_TEST:
    comparison_data[model_name] = [
        all_model_results[model_name]['segment_metrics'][seg]['recall']
        for seg in SEGMENTS
    ]

comparison_df = pd.DataFrame(comparison_data).set_index('Segment')

# Add winner column
comparison_df['Best Model'] = comparison_df[MODELS_TO_TEST].idxmax(axis=1)

display(comparison_df.round(4))

# %%
# Overall comparison (Weighted Recall)
print('\n📊 Overall Comparison (Weighted Recall):')
print('-' * 50)

overall_comparison = []
for model_name in MODELS_TO_TEST:
    w_recall = calculate_weighted_recall(
        all_model_results[model_name]['segment_metrics'], 
        SEGMENT_WEIGHTS
    )
    overall_comparison.append({
        'Model': model_name,
        'Weighted Recall': w_recall
    })
    print(f'   {model_name:20s}: {w_recall:.4f}')

# Best model
best_model_name = max(overall_comparison, key=lambda x: x['Weighted Recall'])['Model']
print(f'\n   🏆 Best Model: {best_model_name}')

# %%
# Visualize: Recall heatmap
fig, ax = plt.subplots(figsize=(10, 6))

recall_matrix = comparison_df[MODELS_TO_TEST]
sns.heatmap(recall_matrix, annot=True, fmt='.3f', cmap='RdYlGn', ax=ax,
            vmin=0, vmax=1, cbar_kws={'label': 'Recall'})
ax.set_title('Recall by Segment and Model (Per-Segment Training)', fontsize=14, fontweight='bold')
ax.set_ylabel('Segment')
ax.set_xlabel('Model')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5️⃣ Experiment 4: Segment Configurations (Per-Segment)
#
# **تست تنظیمات مختلف سگمنت با مدل جداگانه برای هر سگمنت**

# %%
print('='*80)
print('📦 EXPERIMENT 4: Segment Configurations (Per-Segment)')
print('='*80)

# Define different segment configurations
SEGMENT_CONFIGS = {
    '5 Segments (Default)': {
        'segments': {
            '1 Order': {'min': 1, 'max': 1},
            '2-4 Orders': {'min': 2, 'max': 4},
            '5-10 Orders': {'min': 5, 'max': 10},
            '11-30 Orders': {'min': 11, 'max': 30},
            '30+ Orders': {'min': 31, 'max': 99999}
        },
        'weights': {'1 Order': 0.5, '2-4 Orders': 1.0, '5-10 Orders': 1.5, 
                   '11-30 Orders': 2.0, '30+ Orders': 3.0},
        'imbalanced': ['1 Order', '30+ Orders']
    },
    '6 Segments': {
        'segments': {
            '1 Order': {'min': 1, 'max': 1},
            '2-4 Orders': {'min': 2, 'max': 4},
            '5-10 Orders': {'min': 5, 'max': 10},
            '11-20 Orders': {'min': 11, 'max': 20},
            '21-40 Orders': {'min': 21, 'max': 40},
            '40+ Orders': {'min': 41, 'max': 99999}
        },
        'weights': {'1 Order': 0.5, '2-4 Orders': 1.0, '5-10 Orders': 1.5,
                   '11-20 Orders': 2.0, '21-40 Orders': 2.5, '40+ Orders': 3.0},
        'imbalanced': ['1 Order', '40+ Orders']
    },
    '4 Segments': {
        'segments': {
            'New (1-2)': {'min': 1, 'max': 2},
            'Growing (3-10)': {'min': 3, 'max': 10},
            'Established (11-30)': {'min': 11, 'max': 30},
            'Power (30+)': {'min': 31, 'max': 99999}
        },
        'weights': {'New (1-2)': 0.5, 'Growing (3-10)': 1.0,
                   'Established (11-30)': 2.0, 'Power (30+)': 3.0},
        'imbalanced': ['New (1-2)', 'Power (30+)']
    },
    '3 Segments': {
        'segments': {
            'New (1-4)': {'min': 1, 'max': 4},
            'Regular (5-30)': {'min': 5, 'max': 30},
            'Loyal (30+)': {'min': 31, 'max': 99999}
        },
        'weights': {'New (1-4)': 0.5, 'Regular (5-30)': 1.5, 'Loyal (30+)': 3.0},
        'imbalanced': ['New (1-4)', 'Loyal (30+)']
    },
    '2 Segments': {
        'segments': {
            'New (1-10)': {'min': 1, 'max': 10},
            'Loyal (10+)': {'min': 11, 'max': 99999}
        },
        'weights': {'New (1-10)': 0.5, 'Loyal (10+)': 3.0},
        'imbalanced': ['New (1-10)', 'Loyal (10+)']
    }
}

segment_config_results = {}

# %%
for config_name, config in SEGMENT_CONFIGS.items():
    print(f'\n📦 Testing: {config_name}')
    print(f'   Segments: {list(config["segments"].keys())}')

    # Create segmenter
    segmenter = Segmenter.create_custom_segments(config['segments'])

    # Apply segmentation
    train_seg = segmenter.fit_transform(train_df.copy(), order_col='total_orders')
    test_seg = segmenter.transform(test_df.copy(), order_col='total_orders')
    
    # Get new segment list
    new_segments = list(config['segments'].keys())
    
    # Train per-segment models with XGBoost
    result = train_per_segment_models(
        model_name='XGBoost',
        segments=new_segments,
        X_train=X_train_full,
        y_train=y_train_full,
        segments_train=train_seg['segment'],
        X_test=X_test_full,
        y_test=y_test_full,
        segments_test=test_seg['segment'],
        imbalanced_segments=config['imbalanced']
    )
    
    weighted_recall = calculate_weighted_recall(result['segment_metrics'], config['weights'])
    
    segment_config_results[config_name] = {
        'result': result,
        'weighted_recall': weighted_recall,
        'segments': new_segments
    }
    
    print(f'   Weighted Recall: {weighted_recall:.4f}')
    for seg, metrics in result['segment_metrics'].items():
        print(f'      {seg:25s}: Recall={metrics["recall"]:.4f}')

# %%
# Compare configurations
print('\n📊 Segment Configuration Comparison:')
print('-' * 50)

for config_name, data in segment_config_results.items():
    print(f'   {config_name:25s}: Weighted Recall = {data["weighted_recall"]:.4f}')

best_config = max(segment_config_results, key=lambda x: segment_config_results[x]['weighted_recall'])
print(f'\n   🏆 Best Configuration: {best_config}')

# %% [markdown]
# ## 6️⃣ Experiment 5: Auto-Clustering (Per-Cluster)
#
# **کلاسترینگ خودکار + مدل جداگانه برای هر کلاستر**

# %%
print('='*80)
print('🎯 EXPERIMENT 5: Auto-Clustering (Per-Cluster)')
print('='*80)

# Features for clustering
clustering_features = ['total_orders', 'recency', 'tenure_days']
if 'avg_days_between_orders' in feature_cols:
    clustering_features.append('avg_days_between_orders')

print(f'\nClustering features: {clustering_features}')

clustering_results = {}

# %%
# Test different number of clusters
for n_clusters in [2, 3, 4, 5, 6, 10]:
    print(f'\n📦 Testing {n_clusters} clusters...')
    
    # Create clustering segmenter
    segmenter = Segmenter(
        method='clustering',
        config={
            'n_clusters': n_clusters,
            'features': clustering_features
        }
    )
    
    # Apply clustering
    train_clustered = segmenter.fit_transform(train_df.copy())
    test_clustered = segmenter.transform(test_df.copy())
    
    # Show cluster distribution
    cluster_names = [f'Cluster_{i}' for i in range(n_clusters)]
    
    print(f'   Cluster distribution:')
    for cluster in cluster_names:
        mask = test_clustered['segment'] == cluster
        if mask.sum() > 0:
            churn_rate = test_clustered[mask]['is_churned'].mean()
            print(f'      {cluster}: {mask.sum():,} ({churn_rate:.1%} churn)')
    
    # Train per-cluster models
    result = train_per_segment_models(
        model_name='XGBoost',
        segments=cluster_names,
        X_train=X_train_full,
        y_train=y_train_full,
        segments_train=train_clustered['segment'],
        X_test=X_test_full,
        y_test=y_test_full,
        segments_test=test_clustered['segment'],
        imbalanced_segments=[]
    )
    
    # Equal weights for clusters
    cluster_weights = {c: 1.0 for c in cluster_names}
    weighted_recall = calculate_weighted_recall(result['segment_metrics'], cluster_weights)
    
    clustering_results[f'{n_clusters} Clusters'] = {
        'result': result,
        'weighted_recall': weighted_recall,
        'segmenter': segmenter
    }
    
    print(f'   Weighted Recall: {weighted_recall:.4f}')

# %%
# Compare clustering vs manual segmentation
print('\n📊 Clustering vs Manual Segmentation (Per-Segment models):')
print('-' * 60)

print(f'   Manual (5 Segments):  Weighted Recall = {per_segment_weighted_recall:.4f}')
for name, data in clustering_results.items():
    print(f'   {name:20s}: Weighted Recall = {data["weighted_recall"]:.4f}')

# Best approach
all_approaches = {'Manual (5 Segments)': per_segment_weighted_recall}
all_approaches.update({name: data['weighted_recall'] for name, data in clustering_results.items()})
best_approach = max(all_approaches, key=all_approaches.get)
print(f'\n   🏆 Best Approach: {best_approach}')

# %% [markdown]
# ## 7️⃣ Experiment 6: Hyperparameter Tuning (Per-Segment)
#
# **بهینه‌سازی هایپرپارامترهای XGBoost برای هر سگمنت جداگانه**
#
# هایپرپارامترهای مورد تنظیم:
# - `max_depth`: عمق درخت
# - `learning_rate`: نرخ یادگیری
# - `subsample`: نسبت نمونه‌ها برای هر درخت
# - `colsample_bytree`: نسبت فیچرها برای هر درخت
# - `min_child_weight`: حداقل وزن برای ایجاد leaf

# %%
print('='*80)
print('⚙️ EXPERIMENT 6: Hyperparameter Tuning (Per-Segment)')
print('='*80)

from sklearn.model_selection import ParameterGrid

# Define hyperparameter grid
param_grid = {
    'max_depth': [4, 6, 8],
    'learning_rate': [0.05, 0.1, 0.15],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9],
    'min_child_weight': [1, 3, 5],
    'gamma': [0.1, 0.2, 0.3, 0.5],
}

# For efficiency, we'll do a simplified grid search
# Testing key combinations instead of full grid
param_combinations = [
    {'max_depth': 4, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 1},
    {'max_depth': 6, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 1},
    {'max_depth': 8, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 1},
    {'max_depth': 6, 'learning_rate': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 1},
    {'max_depth': 6, 'learning_rate': 0.15, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 1},
    {'max_depth': 6, 'learning_rate': 0.1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1},
    {'max_depth': 6, 'learning_rate': 0.1, 'subsample': 0.9, 'colsample_bytree': 0.9, 'min_child_weight': 1},
    {'max_depth': 6, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 3},
    {'max_depth': 6, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 5},
]

print(f'Testing {len(param_combinations)} parameter combinations per segment')

# %%
from xgboost import XGBClassifier

# Tune hyperparameters for each segment
best_params_per_segment = {}
tuning_results = {}

for segment in SEGMENTS:
    print(f'\n📊 Tuning hyperparameters for: {segment}')
    
    # Get segment data
    train_mask = segments_train_full == segment
    test_mask = segments_test_full == segment
    
    X_train_seg = X_train_full[train_mask]
    y_train_seg = y_train_full[train_mask]
    X_test_seg = X_test_full[test_mask]
    y_test_seg = y_test_full[test_mask]
    
    # Calculate class weight
    scale_pos_weight = calculate_class_weight(y_train_seg.values)
    is_imbalanced = segment in IMBALANCED_SEGMENTS
    
    best_recall = 0
    best_params = None
    segment_results = []
    
    for params in param_combinations:
        # Create model with these params
        model = XGBClassifier(
            n_estimators=200,
            max_depth=params['max_depth'],
            learning_rate=params['learning_rate'],
            subsample=params['subsample'],
            colsample_bytree=params['colsample_bytree'],
            min_child_weight=params['min_child_weight'],
            scale_pos_weight=scale_pos_weight if is_imbalanced else 1.0,
            eval_metric='aucpr',
            early_stopping_rounds=20,
            random_state=RANDOM_STATE
        )
        
        # Train
        model.fit(X_train_seg, y_train_seg, eval_set=[(X_test_seg, y_test_seg)], verbose=False)
        
        # Predict
        y_pred = model.predict(X_test_seg)
        
        # Calculate recall
        recall = recall_score(y_test_seg, y_pred, zero_division=0)
        precision = precision_score(y_test_seg, y_pred, zero_division=0)
        f1 = f1_score(y_test_seg, y_pred, zero_division=0)
        
        segment_results.append({
            'params': params,
            'recall': recall,
            'precision': precision,
            'f1': f1
        })
        
        if recall > best_recall:
            best_recall = recall
            best_params = params
    
    best_params_per_segment[segment] = best_params
    tuning_results[segment] = segment_results
    
    print(f'   Best params: {best_params}')
    print(f'   Best recall: {best_recall:.4f}')

# %%
# Compare default vs tuned performance
print('\n📊 Default vs Tuned Performance:')
print('='*70)

# Train with best params for each segment
tuned_models = {}
tuned_metrics = {}

for segment in SEGMENTS:
    train_mask = segments_train_full == segment
    test_mask = segments_test_full == segment
    
    X_train_seg = X_train_full[train_mask]
    y_train_seg = y_train_full[train_mask]
    X_test_seg = X_test_full[test_mask]
    y_test_seg = y_test_full[test_mask]
    
    scale_pos_weight = calculate_class_weight(y_train_seg.values)
    is_imbalanced = segment in IMBALANCED_SEGMENTS
    params = best_params_per_segment[segment]
    
    # Create tuned model
    from xgboost import XGBClassifier
    model = XGBClassifier(
        n_estimators=5000,
        max_depth=params['max_depth'],
        learning_rate=params['learning_rate'],
        subsample=params['subsample'],
        colsample_bytree=params['colsample_bytree'],
        min_child_weight=params['min_child_weight'],
        scale_pos_weight=scale_pos_weight if is_imbalanced else 1.0,
        eval_metric='aucpr',
        early_stopping_rounds=20,
        random_state=RANDOM_STATE
    )
    
    model.fit(X_train_seg, y_train_seg, eval_set=[(X_test_seg, y_test_seg)], verbose=False)
    
    y_pred = model.predict(X_test_seg)
    y_prob = model.predict_proba(X_test_seg)[:, 1]
    
    tuned_models[segment] = model
    tuned_metrics[segment] = {
        'recall': recall_score(y_test_seg, y_pred, zero_division=0),
        'precision': precision_score(y_test_seg, y_pred, zero_division=0),
        'f1': f1_score(y_test_seg, y_pred, zero_division=0),
        'roc_auc': roc_auc_score(y_test_seg, y_prob) if len(np.unique(y_test_seg)) > 1 else 0,
        'support': len(y_test_seg)
    }

# Calculate weighted recall for tuned models
tuned_weighted_recall = calculate_weighted_recall(tuned_metrics, SEGMENT_WEIGHTS)

print(f'\n   Default Weighted Recall: {per_segment_weighted_recall:.4f}')
print(f'   Tuned Weighted Recall:   {tuned_weighted_recall:.4f}')
print(f'   Improvement:             +{(tuned_weighted_recall - per_segment_weighted_recall)*100:.2f}%')

print('\nPer-Segment Comparison:')
print('-' * 60)
print(f'{"Segment":20s} {"Default":>10s} {"Tuned":>10s} {"Improvement":>12s}')
print('-' * 60)
for segment in SEGMENTS:
    default_r = per_segment_result['segment_metrics'][segment]['recall']
    tuned_r = tuned_metrics[segment]['recall']
    improvement = (tuned_r - default_r) * 100
    print(f'{segment:20s} {default_r:>10.4f} {tuned_r:>10.4f} {improvement:>+11.2f}%')

# %% [markdown]
# ## 8️⃣ Experiment 7: Threshold Optimization (Per-Segment)
#
# **بهینه‌سازی threshold برای هر سگمنت جداگانه**
#
# منطق بهینه‌سازی:
# - هدف: افزایش Recall (شناسایی churners)
# - محدودیت 1: Precision نباید زیر 25% بیاد (FP زیاد نشه)
# - محدودیت 2: Recall نباید زیر 50% بیاد
# - معیار انتخاب: Youden's J (TPR - FPR) با bonus برای F1 بالاتر

# %%
print('='*80)
print('🎚️ EXPERIMENT 7: Threshold Optimization (Per-Segment)')
print('='*80)

# Use tuned models
best_models = tuned_models

# Get predictions for threshold optimization
predictions_for_threshold = {}
for segment in SEGMENTS:
    test_mask = segments_test_full == segment
    X_test_seg = X_test_full[test_mask]
    y_test_seg = y_test_full[test_mask]
    
    y_prob = best_models[segment].predict_proba(X_test_seg)[:, 1]
    
    predictions_for_threshold[segment] = {
        'y_true': y_test_seg.values,
        'y_prob': y_prob
    }

# %%
# Find optimal thresholds using the module function
optimal_thresholds, threshold_details = find_optimal_threshold_per_segment(
    predictions=predictions_for_threshold,
    weights=SEGMENT_WEIGHTS,
    min_precision=0.25,  # At least 25% precision
    min_recall=0.50      # At least 50% recall
)

print('📊 Threshold Optimization Results:')
print('='*80)
print(f'{"Segment":20s} {"Default":>8s} {"Optimal":>8s} {"Recall":>10s} {"Precision":>10s} {"F1":>8s}')
print('-' * 80)

for segment in SEGMENTS:
    d = threshold_details[segment]
    print(f'{segment:20s} {d["default_threshold"]:>8.2f} {d["optimal_threshold"]:>8.2f} '
          f'{d["default_recall"]:>5.3f}→{d["optimal_recall"]:>5.3f} '
          f'{d["default_precision"]:>5.3f}→{d["optimal_precision"]:>5.3f} '
          f'{d["default_f1"]:>4.3f}→{d["optimal_f1"]:>4.3f}')

# %%
# Calculate weighted recall with optimal thresholds
print('\n📊 Weighted Recall Comparison:')
print('-' * 50)

# Default thresholds
default_segment_recalls = {seg: threshold_details[seg]['default_recall'] for seg in SEGMENTS}
default_weighted = sum(default_segment_recalls[seg] * SEGMENT_WEIGHTS[seg] 
                       for seg in SEGMENTS) / sum(SEGMENT_WEIGHTS.values())

# Optimal thresholds
optimal_segment_recalls = {seg: threshold_details[seg]['optimal_recall'] for seg in SEGMENTS}
optimal_weighted = sum(optimal_segment_recalls[seg] * SEGMENT_WEIGHTS[seg] 
                       for seg in SEGMENTS) / sum(SEGMENT_WEIGHTS.values())

print(f'   Default Thresholds (0.5):  Weighted Recall = {default_weighted:.4f}')
print(f'   Optimal Thresholds:        Weighted Recall = {optimal_weighted:.4f}')
print(f'   Improvement:               +{(optimal_weighted - default_weighted)*100:.1f}%')

print(f'\n📋 Optimal Thresholds Summary:')
for seg, thresh in optimal_thresholds.items():
    prec = threshold_details[seg]['optimal_precision']
    rec = threshold_details[seg]['optimal_recall']
    print(f'   {seg:20s}: threshold={thresh:.2f}, recall={rec:.3f}, precision={prec:.3f}')

# %%
# Visualize threshold analysis for each segment
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for idx, segment in enumerate(SEGMENTS):
    ax = axes[idx]
    pred_data = predictions_for_threshold[segment]
    y_true = pred_data['y_true']
    y_prob = pred_data['y_prob']
    
    thresholds = np.linspace(0.1, 0.9, 81)
    recalls = []
    precisions = []
    f1s = []
    fprs = []
    
    for t in thresholds:
        y_pred_t = (y_prob >= t).astype(int)
        recalls.append(recall_score(y_true, y_pred_t, zero_division=0))
        precisions.append(precision_score(y_true, y_pred_t, zero_division=0))
        f1s.append(f1_score(y_true, y_pred_t, zero_division=0))
        # FPR
        n_neg = (y_true == 0).sum()
        fp = ((y_pred_t == 1) & (y_true == 0)).sum()
        fprs.append(fp / n_neg if n_neg > 0 else 0)
    
    ax.plot(thresholds, recalls, 'r-', lw=2, label='Recall (TPR)')
    ax.plot(thresholds, precisions, 'b-', lw=2, label='Precision')
    ax.plot(thresholds, f1s, 'g-', lw=2, label='F1')
    ax.plot(thresholds, fprs, 'm--', lw=1.5, label='FPR', alpha=0.7)
    
    # Reference lines
    ax.axvline(x=0.5, color='gray', linestyle='--', alpha=0.5, label='Default')
    ax.axvline(x=optimal_thresholds[segment], color='red', linestyle='-', 
               lw=2, alpha=0.8, label=f'Optimal ({optimal_thresholds[segment]:.2f})')
    ax.axhline(y=0.25, color='blue', linestyle=':', alpha=0.5)  # Min precision
    
    ax.set_xlabel('Threshold')
    ax.set_ylabel('Score')
    ax.set_title(f'{segment}')
    ax.legend(loc='best', fontsize=7)
    ax.set_xlim([0.1, 0.9])
    ax.set_ylim([0, 1])

# Hide last subplot if odd number
if len(SEGMENTS) < len(axes):
    axes[-1].axis('off')

plt.suptitle('Threshold Optimization per Segment\n(Blue dotted line = min precision constraint)', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9️⃣ Feature Importance & SHAP Analysis (Per-Segment)
#
# **تحلیل feature importance برای بهترین مدل هر سگمنت**

# %%
print('='*80)
print('🔍 Feature Importance & SHAP Analysis (Per-Segment)')
print('='*80)

# %% [markdown]
# ### 9.1 XGBoost Feature Importance (Per-Segment)

# %%
# Extract feature importance from each segment's model
feature_importance_results = {}

for segment in SEGMENTS:
    model = best_models[segment]
    
    # Get feature importance
    importance = model.feature_importances_
    
    importance_df = pd.DataFrame({
        'feature': feature_cols,
        'importance': importance
    }).sort_values('importance', ascending=False)
    
    feature_importance_results[segment] = importance_df

# Show top 10 features for each segment
print('\n📊 Top 10 Features by Segment (XGBoost Importance):')
print('='*80)

top_n = 10
top_features_xgb = {}

for segment in SEGMENTS:
    top_features_xgb[segment] = feature_importance_results[segment].head(top_n)['feature'].tolist()

# Create comparison table
feature_comparison_xgb = pd.DataFrame(top_features_xgb)
feature_comparison_xgb.index = [f'#{i+1}' for i in range(top_n)]
display(feature_comparison_xgb)

# %%
# Plot feature importance for each segment
fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

for idx, segment in enumerate(SEGMENTS):
    ax = axes[idx]
    top_features = feature_importance_results[segment].head(15)
    
    colors = plt.cm.Blues(np.linspace(0.4, 0.8, len(top_features)))
    ax.barh(range(len(top_features)), top_features['importance'].values, color=colors)
    ax.set_yticks(range(len(top_features)))
    ax.set_yticklabels(top_features['feature'].values, fontsize=8)
    ax.invert_yaxis()
    ax.set_xlabel('Importance')
    ax.set_title(f'{segment}', fontsize=11, fontweight='bold')

if len(SEGMENTS) < len(axes):
    axes[-1].axis('off')

plt.suptitle('XGBoost Feature Importance by Segment', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.2 SHAP Analysis (Per-Segment)

# %%
# Calculate SHAP values for each segment
shap_results = {}

for segment in SEGMENTS:
    print(f'\n📊 SHAP Analysis for: {segment}')
    
    model = best_models[segment]
    
    # Get test data for this segment
    test_mask = segments_test_full == segment
    X_test_seg = X_test_full[test_mask]
    
    # Sample for faster computation
    sample_size = min(500, len(X_test_seg))
    X_sample = X_test_seg.sample(n=sample_size, random_state=RANDOM_STATE)
    
    # Calculate SHAP values
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_sample)
    
    # Get feature importance from SHAP
    mean_abs_shap = np.abs(shap_values).mean(axis=0)
    shap_importance_df = pd.DataFrame({
        'feature': feature_cols,
        'shap_importance': mean_abs_shap
    }).sort_values('shap_importance', ascending=False)
    
    shap_results[segment] = {
        'shap_values': shap_values,
        'X_sample': X_sample,
        'importance': shap_importance_df
    }
    
    print(f'   Top 5 features (SHAP):')
    for _, row in shap_importance_df.head(5).iterrows():
        print(f'      {row["feature"]}: {row["shap_importance"]:.4f}')

# %%
# Compare SHAP importance across segments
print('\n📊 Top 10 Features by Segment (SHAP Importance):')
print('='*80)

top_features_shap = {}
for segment in SEGMENTS:
    top_features_shap[segment] = shap_results[segment]['importance'].head(top_n)['feature'].tolist()

feature_comparison_shap = pd.DataFrame(top_features_shap)
feature_comparison_shap.index = [f'#{i+1}' for i in range(top_n)]
display(feature_comparison_shap)

# %%
# Plot SHAP summary for each segment
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

for idx, segment in enumerate(SEGMENTS):
    plt.sca(axes[idx])
    shap.summary_plot(
        shap_results[segment]['shap_values'],
        shap_results[segment]['X_sample'],
        max_display=10,
        show=False,
        plot_size=None
    )
    axes[idx].set_title(f'{segment}', fontsize=12, fontweight='bold')

if len(SEGMENTS) < len(axes):
    axes[-1].axis('off')

plt.suptitle('SHAP Feature Importance by Segment', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Find common important features across all segments
print('\n📊 Common Important Features Across Segments:')
print('='*60)

# Get top 20 features from each segment (both XGBoost and SHAP)
all_top_features = []
for segment in SEGMENTS:
    # From XGBoost importance
    top_xgb = feature_importance_results[segment].head(20)['feature'].tolist()
    all_top_features.extend(top_xgb)
    
    # From SHAP importance
    top_shap = shap_results[segment]['importance'].head(20)['feature'].tolist()
    all_top_features.extend(top_shap)

# Count occurrences
feature_counts = Counter(all_top_features)

print('\nFeatures appearing in top 20 of multiple segments (XGBoost + SHAP):')
max_count = len(SEGMENTS) * 2  # Both methods
for feature, count in feature_counts.most_common(15):
    print(f'   {feature:40s}: {count}/{max_count} times')

# %% [markdown]
# ## 🔟 Save Results

# %%
print('='*80)
print('💾 Saving Results')
print('='*80)

results_path = Path(RESULTS_DIR)

# Save tuned per-segment models
with open(results_path / 'per_segment_tuned_models.pkl', 'wb') as f:
    pickle.dump(best_models, f)
print('✅ Saved: per_segment_tuned_models.pkl')

# Save best hyperparameters
with open(results_path / 'best_hyperparameters.json', 'w') as f:
    json.dump(best_params_per_segment, f, indent=2)
print('✅ Saved: best_hyperparameters.json')

# Save optimal thresholds
with open(results_path / 'optimal_thresholds.json', 'w') as f:
    json.dump(optimal_thresholds, f, indent=2)
print('✅ Saved: optimal_thresholds.json')

# Save model comparison
comparison_df.to_csv(results_path / 'model_comparison_per_segment.csv')
print('✅ Saved: model_comparison_per_segment.csv')

# Save feature importance for each segment
for segment in SEGMENTS:
    safe_name = segment.replace(' ', '_').replace('+', 'plus')
    
    # XGBoost importance
    feature_importance_results[segment].to_csv(
        results_path / f'xgb_importance_{safe_name}.csv', index=False
    )
    
    # SHAP importance
    shap_results[segment]['importance'].to_csv(
        results_path / f'shap_importance_{safe_name}.csv', index=False
    )
print('✅ Saved: Feature importance CSVs (XGBoost + SHAP)')

# Save experiment summary
experiment_summary = {
    'timestamp': datetime.now().isoformat(),
    'approach': 'Per-Segment Models with Hyperparameter Tuning',
    'best_model': 'XGBoost (Tuned)',
    'segments': SEGMENTS,
    'segment_weights': SEGMENT_WEIGHTS,
    'best_hyperparameters': best_params_per_segment,
    'optimal_thresholds': optimal_thresholds,
    'results': {
        'baseline_weighted_recall': float(baseline_weighted_recall),
        'default_per_segment_weighted_recall': float(per_segment_weighted_recall),
        'tuned_weighted_recall': float(tuned_weighted_recall),
        'optimized_threshold_weighted_recall': float(optimal_weighted)
    },
    'top_common_features': [f for f, _ in feature_counts.most_common(10)]
}

with open(results_path / 'experiment_summary.json', 'w') as f:
    json.dump(experiment_summary, f, indent=2)
print('✅ Saved: experiment_summary.json')

# %% [markdown]
# ## 📋 Final Summary

# %%
print('='*80)
print('📋 FINAL SUMMARY')
print('='*80)

print(f'''
🎯 KEY FINDINGS:

1️⃣ BASELINE PERFORMANCE:
   Rule-Based (Recency Threshold): Weighted Recall = {baseline_weighted_recall:.4f}

2️⃣ PER-SEGMENT vs UNIFIED:
   Per-Segment (5 models): Weighted Recall = {per_segment_weighted_recall:.4f}
   Unified (1 model):      Weighted Recall = {unified_weighted_recall:.4f}
   Winner: {'✅ Per-Segment' if per_segment_weighted_recall > unified_weighted_recall else '✅ Unified'}

3️⃣ HYPERPARAMETER TUNING:
   Before Tuning: Weighted Recall = {per_segment_weighted_recall:.4f}
   After Tuning:  Weighted Recall = {tuned_weighted_recall:.4f}
   Improvement: +{(tuned_weighted_recall - per_segment_weighted_recall)*100:.2f}%

4️⃣ THRESHOLD OPTIMIZATION:
   Default (0.5):  Weighted Recall = {default_weighted:.4f}
   Optimal:        Weighted Recall = {optimal_weighted:.4f}
   Improvement: +{(optimal_weighted - default_weighted)*100:.1f}%
''')

print('5️⃣ OPTIMAL THRESHOLDS (با حفظ precision ≥ 25%):')
for seg, thresh in optimal_thresholds.items():
    d = threshold_details[seg]
    print(f'   {seg:20s}: t={thresh:.2f} (R={d["optimal_recall"]:.3f}, P={d["optimal_precision"]:.3f})')

print(f'''
6️⃣ BEST HYPERPARAMETERS PER SEGMENT:
''')
for seg, params in best_params_per_segment.items():
    print(f'   {seg:20s}: depth={params["max_depth"]}, lr={params["learning_rate"]}, '
          f'subsample={params["subsample"]}')

print(f'''
7️⃣ TOP COMMON FEATURES (across all segments):
''')
for feature, count in feature_counts.most_common(7):
    print(f'   • {feature}')

print(f'''
💾 RESULTS SAVED TO:
   {RESULTS_DIR}/
   
📊 FINAL RECOMMENDATIONS:
   ✅ Use Per-Segment XGBoost models with tuned hyperparameters
   ✅ Apply segment-specific thresholds for better recall
   ✅ Focus on top features identified by both XGBoost & SHAP
   ✅ VIP segments (30+ Orders) need special attention
''')
